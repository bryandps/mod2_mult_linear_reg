# %% [markdown]
# # Multiple Linear Regression Lab

# %% [markdown]
# ## Import the relevant libraries

# %%
import numpy as np
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import f_regression
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.preprocessing import StandardScaler
from itertools import chain, combinations

# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
conda install tqdm
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/Bryan/opt/anaconda3
#
#   added / updated specs:
#     - tqdm
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.8.3                |           py37_0         2.8 MB
#     ------------------------------------------------------------
#                                            Total:         2.8 MB
#
# The following packages will be UPDATED:
#
#   conda                                        4.8.2-py37_0 --> 4.8.3-py37_0
#
#
#
# Downloading and Extracting Packages
# conda-4.8.3          | 2.8 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# %%capture

from tqdm import tqdm_notebook as tqdm
from tqdm import tnrange
tqdm().pandas()

# %% [markdown]
# ## Load the data

# %%
df = pd.read_csv('kc_house_data_train.csv')
df.head(10)
# Out:
#    Unnamed: 0          id             date      price  bedrooms  bathrooms  \
# 0           0  2591820310  20141006T000000   365000.0         4       2.25
# 1           1  7974200820  20140821T000000   865000.0         5       3.00
# 2           2  7701450110  20140815T000000  1038000.0         4       2.50
# 3           3  9522300010  20150331T000000  1490000.0         3       3.50
# 4           4  9510861140  20140714T000000   711000.0         3       2.50
# 5           5  1761300310  20140827T000000   211000.0         4       2.00
# 6           6  7732410120  20140819T000000   790000.0         4       2.50
# 7           7  7010701383  20141017T000000   680000.0         3       2.50
# 8           8   291310170  20140804T000000   384500.0         3       2.50
# 9           9  4232901990  20140516T000000   605000.0         2       1.00
#
#    sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 0         2070      8893     2.0           0  ...      8        2070
# 1         2900      6730     1.0           0  ...      8        1830
# 2         3770     10893     2.0           0  ...     11        3770
# 3         4560     14608     2.0           0  ...     12        4560
# 4         2550      5376     2.0           0  ...      9        2550
# 5         1710      8288     1.5           0  ...      7        1710
# 6         2690      8036     2.0           0  ...      9        2690
# 7         1800      4400     1.0           0  ...      7        1350
# 8         1600      2610     2.0           0  ...      8        1600
# 9          910      3600     1.0           0  ...      7         910
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0              0      1986             0    98058  47.4388 -122.162
# 1           1070      1977             0    98115  47.6784 -122.285
# 2              0      1997             0    98006  47.5646 -122.129
# 3              0      1990             0    98034  47.6995 -122.228
# 4              0      2004             0    98052  47.6647 -122.083
# 5              0      1970             0    98031  47.3947 -122.174
# 6              0      1987             0    98007  47.6596 -122.144
# 7            450      1970             0    98199  47.6599 -122.396
# 8              0      2005             0    98027  47.5344 -122.068
# 9              0      1909             0    98119  47.6341 -122.361
#
#    sqft_living15  sqft_lot15
# 0           2390        7700
# 1           2370        6283
# 2           3710        9685
# 3           4050       14226
# 4           2250        4050
# 5           1710        7200
# 6           2420        8087
# 7           1920        4400
# 8           1445        1288
# 9           1720        3600
#
# [10 rows x 22 columns]

# %%
df.shape
# Out:
# (17290, 22)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'date', 'price', 'bedrooms', 'bathrooms',
#        'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view', 'condition',
#        'grade', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated',
#        'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %% [markdown]
# ## List all combinations of features

# %%
features = ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view' , 'condition', 'grade', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated',
       'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15']
features
# Out:
# ['bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %%
def powerset(iterable):
    "powerset([1,2,3]) --> () (1,) (2,) (3,) (1,2) (1,3) (2,3) (1,2,3)"
    s = list(iterable)
    return chain.from_iterable(combinations(s, r) for r in range(len(s) + 1))

# %%
feature_list = list(powerset(features))
feature_list
# Out:
# [(),
#  ('bedrooms',),
#  ('bathrooms',),
#  ('sqft_living',),
#  ('sqft_lot',),
#  ('floors',),
#  ('waterfront',),
#  ('view',),
#  ('condition',),
#  ('grade',),
#  ('sqft_above',),
#  ('sqft_basement',),
#  ('yr_built',),
#  ('yr_renovated',),
#  ('zipcode',),
#  ('lat',),
#  ('long',),
#  ('sqft_living15',),
#  ('sqft_lot15',),
#  ('bedrooms', 'bathrooms'),
#  ('bedrooms', 'sqft_living'),
#  ('bedrooms', 'sqft_lot'),
#  ('bedrooms', 'floors'),
#  ('bedrooms', 'waterfront'),
#  ('bedrooms', 'view'),
#  ('bedrooms', 'condition'),
#  ('bedrooms', 'grade'),
#  ('bedrooms', 'sqft_above'),
#  ('bedrooms', 'sqft_basement'),
#  ('bedrooms', 'yr_built'),
#  ('bedrooms', 'yr_renovated'),
#  ('bedrooms', 'zipcode'),
#  ('bedrooms', 'lat'),
#  ('bedrooms', 'long'),
#  ('bedrooms', 'sqft_living15'),
#  ('bedrooms', 'sqft_lot15'),
#  ('bathrooms', 'sqft_living'),
#  ('bathrooms', 'sqft_lot'),
#  ('bathrooms', 'floors'),
#  ('bathrooms', 'waterfront'),
#  ('bathrooms', 'view'),
#  ('bathrooms', 'condition'),
#  ('bathrooms', 'grade'),
#  ('bathrooms', 'sqft_above'),
#  ('bathrooms', 'sqft_basement'),
#  ('bathrooms', 'yr_built'),
#  ('bathrooms', 'yr_renovated'),
#  ('bathrooms', 'zipcode'),
#  ('bathrooms', 'lat'),
#  ('bathrooms', 'long'),
#  ('bathrooms', 'sqft_living15'),
#  ('bathrooms', 'sqft_lot15'),
#  ('sqft_living', 'sqft_lot'),
#  ('sqft_living', 'floors'),
#  ('sqft_living', 'waterfront'),
#  ('sqft_living', 'view'),
#  ('sqft_living', 'condition'),
#  ('sqft_living', 'grade'),
#  ('sqft_living', 'sqft_above'),
#  ('sqft_living', 'sqft_basement'),
#  ('sqft_living', 'yr_built'),
#  ('sqft_living', 'yr_renovated'),
#  ('sqft_living', 'zipcode'),
#  ('sqft_living', 'lat'),
#  ('sqft_living', 'long'),
#  ('sqft_living', 'sqft_living15'),
#  ('sqft_living', 'sqft_lot15'),
#  ('sqft_lot', 'floors'),
#  ('sqft_lot', 'waterfront'),
#  ('sqft_lot', 'view'),
#  ('sqft_lot', 'condition'),
#  ('sqft_lot', 'grade'),
#  ('sqft_lot', 'sqft_above'),
#  ('sqft_lot', 'sqft_basement'),
#  ('sqft_lot', 'yr_built'),
#  ('sqft_lot', 'yr_renovated'),
#  ('sqft_lot', 'zipcode'),
#  ('sqft_lot', 'lat'),
#  ('sqft_lot', 'long'),
#  ('sqft_lot', 'sqft_living15'),
#  ('sqft_lot', 'sqft_lot15'),
#  ('floors', 'waterfront'),
#  ('floors', 'view'),
#  ('floors', 'condition'),
#  ('floors', 'grade'),
#  ('floors', 'sqft_above'),
#  ('floors', 'sqft_basement'),
#  ('floors', 'yr_built'),
#  ('floors', 'yr_renovated'),
#  ('floors', 'zipcode'),
#  ('floors', 'lat'),
#  ('floors', 'long'),
#  ('floors', 'sqft_living15'),
#  ('floors', 'sqft_lot15'),
#  ('waterfront', 'view'),
#  ('waterfront', 'condition'),
#  ('waterfront', 'grade'),
#  ('waterfront', 'sqft_above'),
#  ('waterfront', 'sqft_basement'),
#  ('waterfront', 'yr_built'),
#  ('waterfront', 'yr_renovated'),
#  ('waterfront', 'zipcode'),
#  ('waterfront', 'lat'),
#  ('waterfront', 'long'),
#  ('waterfront', 'sqft_living15'),
#  ('waterfront', 'sqft_lot15'),
#  ('view', 'condition'),
#  ('view', 'grade'),
#  ('view', 'sqft_above'),
#  ('view', 'sqft_basement'),
#  ('view', 'yr_built'),
#  ('view', 'yr_renovated'),
#  ('view', 'zipcode'),
#  ('view', 'lat'),
#  ('view', 'long'),
#  ('view', 'sqft_living15'),
#  ('view', 'sqft_lot15'),
#  ('condition', 'grade'),
#  ('condition', 'sqft_above'),
#  ('condition', 'sqft_basement'),
#  ('condition', 'yr_built'),
#  ('condition', 'yr_renovated'),
#  ('condition', 'zipcode'),
#  ('condition', 'lat'),
#  ('condition', 'long'),
#  ('condition', 'sqft_living15'),
#  ('condition', 'sqft_lot15'),
#  ('grade', 'sqft_above'),
#  ('grade', 'sqft_basement'),
#  ('grade', 'yr_built'),
#  ('grade', 'yr_renovated'),
#  ('grade', 'zipcode'),
#  ('grade', 'lat'),
#  ('grade', 'long'),
#  ('grade', 'sqft_living15'),
#  ('grade', 'sqft_lot15'),
#  ('sqft_above', 'sqft_basement'),
#  ('sqft_above', 'yr_built'),
#  ('sqft_above', 'yr_renovated'),
#  ('sqft_above', 'zipcode'),
#  ('sqft_above', 'lat'),
#  ('sqft_above', 'long'),
#  ('sqft_above', 'sqft_living15'),
#  ('sqft_above', 'sqft_lot15'),
#  ('sqft_basement', 'yr_built'),
#  ('sqft_basement', 'yr_renovated'),
#  ('sqft_basement', 'zipcode'),
#  ('sqft_basement', 'lat'),
#  ('sqft_basement', 'long'),
#  ('sqft_basement', 'sqft_living15'),
#  ('sqft_basement', 'sqft_lot15'),
#  ('yr_built', 'yr_renovated'),
#  ('yr_built', 'zipcode'),
#  ('yr_built', 'lat'),
#  ('yr_built', 'long'),
#  ('yr_built', 'sqft_living15'),
#  ('yr_built', 'sqft_lot15'),
#  ('yr_renovated', 'zipcode'),
#  ('yr_renovated', 'lat'),
#  ('yr_renovated', 'long'),
#  ('yr_renovated', 'sqft_living15'),
#  ('yr_renovated', 'sqft_lot15'),
#  ('zipcode', 'lat'),
#  ('zipcode', 'long'),
#  ('zipcode', 'sqft_living15'),
#  ('zipcode', 'sqft_lot15'),
#  ('lat', 'long'),
#  ('lat', 'sqft_living15'),
#  ('lat', 'sqft_lot15'),
#  ('long', 'sqft_living15'),
#  ('long', 'sqft_lot15'),
#  ('sqft_living15', 'sqft_lot15'),
#  ('bedrooms', 'bathrooms', 'sqft_living'),
#  ('bedrooms', 'bathrooms', 'sqft_lot'),
#  ('bedrooms', 'bathrooms', 'floors'),
#  ('bedrooms', 'bathrooms', 'waterfront'),
#  ('bedrooms', 'bathrooms', 'view'),
#  ('bedrooms', 'bathrooms', 'condition'),
#  ('bedrooms', 'bathrooms', 'grade'),
#  ('bedrooms', 'bathrooms', 'sqft_above'),
#  ('bedrooms', 'bathrooms', 'sqft_basement'),
#  ('bedrooms', 'bathrooms', 'yr_built'),
#  ('bedrooms', 'bathrooms', 'yr_renovated'),
#  ('bedrooms', 'bathrooms', 'zipcode'),
#  ('bedrooms', 'bathrooms', 'lat'),
#  ('bedrooms', 'bathrooms', 'long'),
#  ('bedrooms', 'bathrooms', 'sqft_living15'),
#  ('bedrooms', 'bathrooms', 'sqft_lot15'),
#  ('bedrooms', 'sqft_living', 'sqft_lot'),
#  ('bedrooms', 'sqft_living', 'floors'),
#  ('bedrooms', 'sqft_living', 'waterfront'),
#  ('bedrooms', 'sqft_living', 'view'),
#  ('bedrooms', 'sqft_living', 'condition'),
#  ('bedrooms', 'sqft_living', 'grade'),
#  ('bedrooms', 'sqft_living', 'sqft_above'),
#  ('bedrooms', 'sqft_living', 'sqft_basement'),
#  ('bedrooms', 'sqft_living', 'yr_built'),
#  ('bedrooms', 'sqft_living', 'yr_renovated'),
#  ('bedrooms', 'sqft_living', 'zipcode'),
#  ('bedrooms', 'sqft_living', 'lat'),
#  ('bedrooms', 'sqft_living', 'long'),
#  ('bedrooms', 'sqft_living', 'sqft_living15'),
#  ('bedrooms', 'sqft_living', 'sqft_lot15'),
#  ('bedrooms', 'sqft_lot', 'floors'),
#  ('bedrooms', 'sqft_lot', 'waterfront'),
#  ('bedrooms', 'sqft_lot', 'view'),
#  ('bedrooms', 'sqft_lot', 'condition'),
#  ('bedrooms', 'sqft_lot', 'grade'),
#  ('bedrooms', 'sqft_lot', 'sqft_above'),
#  ('bedrooms', 'sqft_lot', 'sqft_basement'),
#  ('bedrooms', 'sqft_lot', 'yr_built'),
#  ('bedrooms', 'sqft_lot', 'yr_renovated'),
#  ('bedrooms', 'sqft_lot', 'zipcode'),
#  ('bedrooms', 'sqft_lot', 'lat'),
#  ('bedrooms', 'sqft_lot', 'long'),
#  ('bedrooms', 'sqft_lot', 'sqft_living15'),
#  ('bedrooms', 'sqft_lot', 'sqft_lot15'),
#  ('bedrooms', 'floors', 'waterfront'),
#  ('bedrooms', 'floors', 'view'),
#  ('bedrooms', 'floors', 'condition'),
#  ('bedrooms', 'floors', 'grade'),
#  ('bedrooms', 'floors', 'sqft_above'),
#  ('bedrooms', 'floors', 'sqft_basement'),
#  ('bedrooms', 'floors', 'yr_built'),
#  ('bedrooms', 'floors', 'yr_renovated'),
#  ('bedrooms', 'floors', 'zipcode'),
#  ('bedrooms', 'floors', 'lat'),
#  ('bedrooms', 'floors', 'long'),
#  ('bedrooms', 'floors', 'sqft_living15'),
#  ('bedrooms', 'floors', 'sqft_lot15'),
#  ('bedrooms', 'waterfront', 'view'),
#  ('bedrooms', 'waterfront', 'condition'),
#  ('bedrooms', 'waterfront', 'grade'),
#  ('bedrooms', 'waterfront', 'sqft_above'),
#  ('bedrooms', 'waterfront', 'sqft_basement'),
#  ('bedrooms', 'waterfront', 'yr_built'),
#  ('bedrooms', 'waterfront', 'yr_renovated'),
#  ('bedrooms', 'waterfront', 'zipcode'),
#  ('bedrooms', 'waterfront', 'lat'),
#  ('bedrooms', 'waterfront', 'long'),
#  ('bedrooms', 'waterfront', 'sqft_living15'),
#  ('bedrooms', 'waterfront', 'sqft_lot15'),
#  ('bedrooms', 'view', 'condition'),
#  ('bedrooms', 'view', 'grade'),
#  ('bedrooms', 'view', 'sqft_above'),
#  ('bedrooms', 'view', 'sqft_basement'),
#  ('bedrooms', 'view', 'yr_built'),
#  ('bedrooms', 'view', 'yr_renovated'),
#  ('bedrooms', 'view', 'zipcode'),
#  ('bedrooms', 'view', 'lat'),
#  ('bedrooms', 'view', 'long'),
#  ('bedrooms', 'view', 'sqft_living15'),
#  ('bedrooms', 'view', 'sqft_lot15'),
#  ('bedrooms', 'condition', 'grade'),
#  ('bedrooms', 'condition', 'sqft_above'),
#  ('bedrooms', 'condition', 'sqft_basement'),
#  ('bedrooms', 'condition', 'yr_built'),
#  ('bedrooms', 'condition', 'yr_renovated'),
#  ('bedrooms', 'condition', 'zipcode'),
#  ('bedrooms', 'condition', 'lat'),
#  ('bedrooms', 'condition', 'long'),
#  ('bedrooms', 'condition', 'sqft_living15'),
#  ('bedrooms', 'condition', 'sqft_lot15'),
#  ('bedrooms', 'grade', 'sqft_above'),
#  ('bedrooms', 'grade', 'sqft_basement'),
#  ('bedrooms', 'grade', 'yr_built'),
#  ('bedrooms', 'grade', 'yr_renovated'),
#  ('bedrooms', 'grade', 'zipcode'),
#  ('bedrooms', 'grade', 'lat'),
#  ('bedrooms', 'grade', 'long'),
#  ('bedrooms', 'grade', 'sqft_living15'),
#  ('bedrooms', 'grade', 'sqft_lot15'),
#  ('bedrooms', 'sqft_above', 'sqft_basement'),
#  ('bedrooms', 'sqft_above', 'yr_built'),
#  ('bedrooms', 'sqft_above', 'yr_renovated'),
#  ('bedrooms', 'sqft_above', 'zipcode'),
#  ('bedrooms', 'sqft_above', 'lat'),
#  ('bedrooms', 'sqft_above', 'long'),
#  ('bedrooms', 'sqft_above', 'sqft_living15'),
#  ('bedrooms', 'sqft_above', 'sqft_lot15'),
#  ('bedrooms', 'sqft_basement', 'yr_built'),
#  ('bedrooms', 'sqft_basement', 'yr_renovated'),
#  ('bedrooms', 'sqft_basement', 'zipcode'),
#  ('bedrooms', 'sqft_basement', 'lat'),
#  ('bedrooms', 'sqft_basement', 'long'),
#  ('bedrooms', 'sqft_basement', 'sqft_living15'),
#  ('bedrooms', 'sqft_basement', 'sqft_lot15'),
#  ('bedrooms', 'yr_built', 'yr_renovated'),
#  ('bedrooms', 'yr_built', 'zipcode'),
#  ('bedrooms', 'yr_built', 'lat'),
#  ('bedrooms', 'yr_built', 'long'),
#  ('bedrooms', 'yr_built', 'sqft_living15'),
#  ('bedrooms', 'yr_built', 'sqft_lot15'),
#  ('bedrooms', 'yr_renovated', 'zipcode'),
#  ('bedrooms', 'yr_renovated', 'lat'),
#  ('bedrooms', 'yr_renovated', 'long'),
#  ('bedrooms', 'yr_renovated', 'sqft_living15'),
#  ('bedrooms', 'yr_renovated', 'sqft_lot15'),
#  ('bedrooms', 'zipcode', 'lat'),
#  ('bedrooms', 'zipcode', 'long'),
#  ('bedrooms', 'zipcode', 'sqft_living15'),
#  ('bedrooms', 'zipcode', 'sqft_lot15'),
#  ('bedrooms', 'lat', 'long'),
#  ('bedrooms', 'lat', 'sqft_living15'),
#  ('bedrooms', 'lat', 'sqft_lot15'),
#  ('bedrooms', 'long', 'sqft_living15'),
#  ('bedrooms', 'long', 'sqft_lot15'),
#  ('bedrooms', 'sqft_living15', 'sqft_lot15'),
#  ('bathrooms', 'sqft_living', 'sqft_lot'),
#  ('bathrooms', 'sqft_living', 'floors'),
#  ('bathrooms', 'sqft_living', 'waterfront'),
#  ('bathrooms', 'sqft_living', 'view'),
#  ('bathrooms', 'sqft_living', 'condition'),
#  ('bathrooms', 'sqft_living', 'grade'),
#  ('bathrooms', 'sqft_living', 'sqft_above'),
#  ('bathrooms', 'sqft_living', 'sqft_basement'),
#  ('bathrooms', 'sqft_living', 'yr_built'),
#  ('bathrooms', 'sqft_living', 'yr_renovated'),
#  ('bathrooms', 'sqft_living', 'zipcode'),
#  ('bathrooms', 'sqft_living', 'lat'),
#  ('bathrooms', 'sqft_living', 'long'),
#  ('bathrooms', 'sqft_living', 'sqft_living15'),
#  ('bathrooms', 'sqft_living', 'sqft_lot15'),
#  ('bathrooms', 'sqft_lot', 'floors'),
#  ('bathrooms', 'sqft_lot', 'waterfront'),
#  ('bathrooms', 'sqft_lot', 'view'),
#  ('bathrooms', 'sqft_lot', 'condition'),
#  ('bathrooms', 'sqft_lot', 'grade'),
#  ('bathrooms', 'sqft_lot', 'sqft_above'),
#  ('bathrooms', 'sqft_lot', 'sqft_basement'),
#  ('bathrooms', 'sqft_lot', 'yr_built'),
#  ('bathrooms', 'sqft_lot', 'yr_renovated'),
#  ('bathrooms', 'sqft_lot', 'zipcode'),
#  ('bathrooms', 'sqft_lot', 'lat'),
#  ('bathrooms', 'sqft_lot', 'long'),
#  ('bathrooms', 'sqft_lot', 'sqft_living15'),
#  ('bathrooms', 'sqft_lot', 'sqft_lot15'),
#  ('bathrooms', 'floors', 'waterfront'),
#  ('bathrooms', 'floors', 'view'),
#  ('bathrooms', 'floors', 'condition'),
#  ('bathrooms', 'floors', 'grade'),
#  ('bathrooms', 'floors', 'sqft_above'),
#  ('bathrooms', 'floors', 'sqft_basement'),
#  ('bathrooms', 'floors', 'yr_built'),
#  ('bathrooms', 'floors', 'yr_renovated'),
#  ('bathrooms', 'floors', 'zipcode'),
#  ('bathrooms', 'floors', 'lat'),
#  ('bathrooms', 'floors', 'long'),
#  ('bathrooms', 'floors', 'sqft_living15'),
#  ('bathrooms', 'floors', 'sqft_lot15'),
#  ('bathrooms', 'waterfront', 'view'),
#  ('bathrooms', 'waterfront', 'condition'),
#  ('bathrooms', 'waterfront', 'grade'),
#  ('bathrooms', 'waterfront', 'sqft_above'),
#  ('bathrooms', 'waterfront', 'sqft_basement'),
#  ('bathrooms', 'waterfront', 'yr_built'),
#  ('bathrooms', 'waterfront', 'yr_renovated'),
#  ('bathrooms', 'waterfront', 'zipcode'),
#  ('bathrooms', 'waterfront', 'lat'),
#  ('bathrooms', 'waterfront', 'long'),
#  ('bathrooms', 'waterfront', 'sqft_living15'),
#  ('bathrooms', 'waterfront', 'sqft_lot15'),
#  ('bathrooms', 'view', 'condition'),
#  ('bathrooms', 'view', 'grade'),
#  ('bathrooms', 'view', 'sqft_above'),
#  ('bathrooms', 'view', 'sqft_basement'),
#  ('bathrooms', 'view', 'yr_built'),
#  ('bathrooms', 'view', 'yr_renovated'),
#  ('bathrooms', 'view', 'zipcode'),
#  ('bathrooms', 'view', 'lat'),
#  ('bathrooms', 'view', 'long'),
#  ('bathrooms', 'view', 'sqft_living15'),
#  ('bathrooms', 'view', 'sqft_lot15'),
#  ('bathrooms', 'condition', 'grade'),
#  ('bathrooms', 'condition', 'sqft_above'),
#  ('bathrooms', 'condition', 'sqft_basement'),
#  ('bathrooms', 'condition', 'yr_built'),
#  ('bathrooms', 'condition', 'yr_renovated'),
#  ('bathrooms', 'condition', 'zipcode'),
#  ('bathrooms', 'condition', 'lat'),
#  ('bathrooms', 'condition', 'long'),
#  ('bathrooms', 'condition', 'sqft_living15'),
#  ('bathrooms', 'condition', 'sqft_lot15'),
#  ('bathrooms', 'grade', 'sqft_above'),
#  ('bathrooms', 'grade', 'sqft_basement'),
#  ('bathrooms', 'grade', 'yr_built'),
#  ('bathrooms', 'grade', 'yr_renovated'),
#  ('bathrooms', 'grade', 'zipcode'),
#  ('bathrooms', 'grade', 'lat'),
#  ('bathrooms', 'grade', 'long'),
#  ('bathrooms', 'grade', 'sqft_living15'),
#  ('bathrooms', 'grade', 'sqft_lot15'),
#  ('bathrooms', 'sqft_above', 'sqft_basement'),
#  ('bathrooms', 'sqft_above', 'yr_built'),
#  ('bathrooms', 'sqft_above', 'yr_renovated'),
#  ('bathrooms', 'sqft_above', 'zipcode'),
#  ('bathrooms', 'sqft_above', 'lat'),
#  ('bathrooms', 'sqft_above', 'long'),
#  ('bathrooms', 'sqft_above', 'sqft_living15'),
#  ('bathrooms', 'sqft_above', 'sqft_lot15'),
#  ('bathrooms', 'sqft_basement', 'yr_built'),
#  ('bathrooms', 'sqft_basement', 'yr_renovated'),
#  ('bathrooms', 'sqft_basement', 'zipcode'),
#  ('bathrooms', 'sqft_basement', 'lat'),
#  ('bathrooms', 'sqft_basement', 'long'),
#  ('bathrooms', 'sqft_basement', 'sqft_living15'),
#  ('bathrooms', 'sqft_basement', 'sqft_lot15'),
#  ('bathrooms', 'yr_built', 'yr_renovated'),
#  ('bathrooms', 'yr_built', 'zipcode'),
#  ('bathrooms', 'yr_built', 'lat'),
#  ('bathrooms', 'yr_built', 'long'),
#  ('bathrooms', 'yr_built', 'sqft_living15'),
#  ('bathrooms', 'yr_built', 'sqft_lot15'),
#  ('bathrooms', 'yr_renovated', 'zipcode'),
#  ('bathrooms', 'yr_renovated', 'lat'),
#  ('bathrooms', 'yr_renovated', 'long'),
#  ('bathrooms', 'yr_renovated', 'sqft_living15'),
#  ('bathrooms', 'yr_renovated', 'sqft_lot15'),
#  ('bathrooms', 'zipcode', 'lat'),
#  ('bathrooms', 'zipcode', 'long'),
#  ('bathrooms', 'zipcode', 'sqft_living15'),
#  ('bathrooms', 'zipcode', 'sqft_lot15'),
#  ('bathrooms', 'lat', 'long'),
#  ('bathrooms', 'lat', 'sqft_living15'),
#  ('bathrooms', 'lat', 'sqft_lot15'),
#  ('bathrooms', 'long', 'sqft_living15'),
#  ('bathrooms', 'long', 'sqft_lot15'),
#  ('bathrooms', 'sqft_living15', 'sqft_lot15'),
#  ('sqft_living', 'sqft_lot', 'floors'),
#  ('sqft_living', 'sqft_lot', 'waterfront'),
#  ('sqft_living', 'sqft_lot', 'view'),
#  ('sqft_living', 'sqft_lot', 'condition'),
#  ('sqft_living', 'sqft_lot', 'grade'),
#  ('sqft_living', 'sqft_lot', 'sqft_above'),
#  ('sqft_living', 'sqft_lot', 'sqft_basement'),
#  ('sqft_living', 'sqft_lot', 'yr_built'),
#  ('sqft_living', 'sqft_lot', 'yr_renovated'),
#  ('sqft_living', 'sqft_lot', 'zipcode'),
#  ('sqft_living', 'sqft_lot', 'lat'),
#  ('sqft_living', 'sqft_lot', 'long'),
#  ('sqft_living', 'sqft_lot', 'sqft_living15'),
#  ('sqft_living', 'sqft_lot', 'sqft_lot15'),
#  ('sqft_living', 'floors', 'waterfront'),
#  ('sqft_living', 'floors', 'view'),
#  ('sqft_living', 'floors', 'condition'),
#  ('sqft_living', 'floors', 'grade'),
#  ('sqft_living', 'floors', 'sqft_above'),
#  ('sqft_living', 'floors', 'sqft_basement'),
#  ('sqft_living', 'floors', 'yr_built'),
#  ('sqft_living', 'floors', 'yr_renovated'),
#  ('sqft_living', 'floors', 'zipcode'),
#  ('sqft_living', 'floors', 'lat'),
#  ('sqft_living', 'floors', 'long'),
#  ('sqft_living', 'floors', 'sqft_living15'),
#  ('sqft_living', 'floors', 'sqft_lot15'),
#  ('sqft_living', 'waterfront', 'view'),
#  ('sqft_living', 'waterfront', 'condition'),
#  ('sqft_living', 'waterfront', 'grade'),
#  ('sqft_living', 'waterfront', 'sqft_above'),
#  ('sqft_living', 'waterfront', 'sqft_basement'),
#  ('sqft_living', 'waterfront', 'yr_built'),
#  ('sqft_living', 'waterfront', 'yr_renovated'),
#  ('sqft_living', 'waterfront', 'zipcode'),
#  ('sqft_living', 'waterfront', 'lat'),
#  ('sqft_living', 'waterfront', 'long'),
#  ('sqft_living', 'waterfront', 'sqft_living15'),
#  ('sqft_living', 'waterfront', 'sqft_lot15'),
#  ('sqft_living', 'view', 'condition'),
#  ('sqft_living', 'view', 'grade'),
#  ('sqft_living', 'view', 'sqft_above'),
#  ('sqft_living', 'view', 'sqft_basement'),
#  ('sqft_living', 'view', 'yr_built'),
#  ('sqft_living', 'view', 'yr_renovated'),
#  ('sqft_living', 'view', 'zipcode'),
#  ('sqft_living', 'view', 'lat'),
#  ('sqft_living', 'view', 'long'),
#  ('sqft_living', 'view', 'sqft_living15'),
#  ('sqft_living', 'view', 'sqft_lot15'),
#  ('sqft_living', 'condition', 'grade'),
#  ('sqft_living', 'condition', 'sqft_above'),
#  ('sqft_living', 'condition', 'sqft_basement'),
#  ('sqft_living', 'condition', 'yr_built'),
#  ('sqft_living', 'condition', 'yr_renovated'),
#  ('sqft_living', 'condition', 'zipcode'),
#  ('sqft_living', 'condition', 'lat'),
#  ('sqft_living', 'condition', 'long'),
#  ('sqft_living', 'condition', 'sqft_living15'),
#  ('sqft_living', 'condition', 'sqft_lot15'),
#  ('sqft_living', 'grade', 'sqft_above'),
#  ('sqft_living', 'grade', 'sqft_basement'),
#  ('sqft_living', 'grade', 'yr_built'),
#  ('sqft_living', 'grade', 'yr_renovated'),
#  ('sqft_living', 'grade', 'zipcode'),
#  ('sqft_living', 'grade', 'lat'),
#  ('sqft_living', 'grade', 'long'),
#  ('sqft_living', 'grade', 'sqft_living15'),
#  ('sqft_living', 'grade', 'sqft_lot15'),
#  ('sqft_living', 'sqft_above', 'sqft_basement'),
#  ('sqft_living', 'sqft_above', 'yr_built'),
#  ('sqft_living', 'sqft_above', 'yr_renovated'),
#  ('sqft_living', 'sqft_above', 'zipcode'),
#  ('sqft_living', 'sqft_above', 'lat'),
#  ('sqft_living', 'sqft_above', 'long'),
#  ('sqft_living', 'sqft_above', 'sqft_living15'),
#  ('sqft_living', 'sqft_above', 'sqft_lot15'),
#  ('sqft_living', 'sqft_basement', 'yr_built'),
#  ('sqft_living', 'sqft_basement', 'yr_renovated'),
#  ('sqft_living', 'sqft_basement', 'zipcode'),
#  ('sqft_living', 'sqft_basement', 'lat'),
#  ('sqft_living', 'sqft_basement', 'long'),
#  ('sqft_living', 'sqft_basement', 'sqft_living15'),
#  ('sqft_living', 'sqft_basement', 'sqft_lot15'),
#  ('sqft_living', 'yr_built', 'yr_renovated'),
#  ('sqft_living', 'yr_built', 'zipcode'),
#  ('sqft_living', 'yr_built', 'lat'),
#  ('sqft_living', 'yr_built', 'long'),
#  ('sqft_living', 'yr_built', 'sqft_living15'),
#  ('sqft_living', 'yr_built', 'sqft_lot15'),
#  ('sqft_living', 'yr_renovated', 'zipcode'),
#  ('sqft_living', 'yr_renovated', 'lat'),
#  ('sqft_living', 'yr_renovated', 'long'),
#  ('sqft_living', 'yr_renovated', 'sqft_living15'),
#  ('sqft_living', 'yr_renovated', 'sqft_lot15'),
#  ('sqft_living', 'zipcode', 'lat'),
#  ('sqft_living', 'zipcode', 'long'),
#  ('sqft_living', 'zipcode', 'sqft_living15'),
#  ('sqft_living', 'zipcode', 'sqft_lot15'),
#  ('sqft_living', 'lat', 'long'),
#  ('sqft_living', 'lat', 'sqft_living15'),
#  ('sqft_living', 'lat', 'sqft_lot15'),
#  ('sqft_living', 'long', 'sqft_living15'),
#  ('sqft_living', 'long', 'sqft_lot15'),
#  ('sqft_living', 'sqft_living15', 'sqft_lot15'),
#  ('sqft_lot', 'floors', 'waterfront'),
#  ('sqft_lot', 'floors', 'view'),
#  ('sqft_lot', 'floors', 'condition'),
#  ('sqft_lot', 'floors', 'grade'),
#  ('sqft_lot', 'floors', 'sqft_above'),
#  ('sqft_lot', 'floors', 'sqft_basement'),
#  ('sqft_lot', 'floors', 'yr_built'),
#  ('sqft_lot', 'floors', 'yr_renovated'),
#  ('sqft_lot', 'floors', 'zipcode'),
#  ('sqft_lot', 'floors', 'lat'),
#  ('sqft_lot', 'floors', 'long'),
#  ('sqft_lot', 'floors', 'sqft_living15'),
#  ('sqft_lot', 'floors', 'sqft_lot15'),
#  ('sqft_lot', 'waterfront', 'view'),
#  ('sqft_lot', 'waterfront', 'condition'),
#  ('sqft_lot', 'waterfront', 'grade'),
#  ('sqft_lot', 'waterfront', 'sqft_above'),
#  ('sqft_lot', 'waterfront', 'sqft_basement'),
#  ('sqft_lot', 'waterfront', 'yr_built'),
#  ('sqft_lot', 'waterfront', 'yr_renovated'),
#  ('sqft_lot', 'waterfront', 'zipcode'),
#  ('sqft_lot', 'waterfront', 'lat'),
#  ('sqft_lot', 'waterfront', 'long'),
#  ('sqft_lot', 'waterfront', 'sqft_living15'),
#  ('sqft_lot', 'waterfront', 'sqft_lot15'),
#  ('sqft_lot', 'view', 'condition'),
#  ('sqft_lot', 'view', 'grade'),
#  ('sqft_lot', 'view', 'sqft_above'),
#  ('sqft_lot', 'view', 'sqft_basement'),
#  ('sqft_lot', 'view', 'yr_built'),
#  ('sqft_lot', 'view', 'yr_renovated'),
#  ('sqft_lot', 'view', 'zipcode'),
#  ('sqft_lot', 'view', 'lat'),
#  ('sqft_lot', 'view', 'long'),
#  ('sqft_lot', 'view', 'sqft_living15'),
#  ('sqft_lot', 'view', 'sqft_lot15'),
#  ('sqft_lot', 'condition', 'grade'),
#  ('sqft_lot', 'condition', 'sqft_above'),
#  ('sqft_lot', 'condition', 'sqft_basement'),
#  ('sqft_lot', 'condition', 'yr_built'),
#  ('sqft_lot', 'condition', 'yr_renovated'),
#  ('sqft_lot', 'condition', 'zipcode'),
#  ('sqft_lot', 'condition', 'lat'),
#  ('sqft_lot', 'condition', 'long'),
#  ('sqft_lot', 'condition', 'sqft_living15'),
#  ('sqft_lot', 'condition', 'sqft_lot15'),
#  ('sqft_lot', 'grade', 'sqft_above'),
#  ('sqft_lot', 'grade', 'sqft_basement'),
#  ('sqft_lot', 'grade', 'yr_built'),
#  ('sqft_lot', 'grade', 'yr_renovated'),
#  ('sqft_lot', 'grade', 'zipcode'),
#  ('sqft_lot', 'grade', 'lat'),
#  ('sqft_lot', 'grade', 'long'),
#  ('sqft_lot', 'grade', 'sqft_living15'),
#  ('sqft_lot', 'grade', 'sqft_lot15'),
#  ('sqft_lot', 'sqft_above', 'sqft_basement'),
#  ('sqft_lot', 'sqft_above', 'yr_built'),
#  ('sqft_lot', 'sqft_above', 'yr_renovated'),
#  ('sqft_lot', 'sqft_above', 'zipcode'),
#  ('sqft_lot', 'sqft_above', 'lat'),
#  ('sqft_lot', 'sqft_above', 'long'),
#  ('sqft_lot', 'sqft_above', 'sqft_living15'),
#  ('sqft_lot', 'sqft_above', 'sqft_lot15'),
#  ('sqft_lot', 'sqft_basement', 'yr_built'),
#  ('sqft_lot', 'sqft_basement', 'yr_renovated'),
#  ('sqft_lot', 'sqft_basement', 'zipcode'),
#  ('sqft_lot', 'sqft_basement', 'lat'),
#  ('sqft_lot', 'sqft_basement', 'long'),
#  ('sqft_lot', 'sqft_basement', 'sqft_living15'),
#  ('sqft_lot', 'sqft_basement', 'sqft_lot15'),
#  ('sqft_lot', 'yr_built', 'yr_renovated'),
#  ('sqft_lot', 'yr_built', 'zipcode'),
#  ('sqft_lot', 'yr_built', 'lat'),
#  ('sqft_lot', 'yr_built', 'long'),
#  ('sqft_lot', 'yr_built', 'sqft_living15'),
#  ('sqft_lot', 'yr_built', 'sqft_lot15'),
#  ('sqft_lot', 'yr_renovated', 'zipcode'),
#  ('sqft_lot', 'yr_renovated', 'lat'),
#  ('sqft_lot', 'yr_renovated', 'long'),
#  ('sqft_lot', 'yr_renovated', 'sqft_living15'),
#  ('sqft_lot', 'yr_renovated', 'sqft_lot15'),
#  ('sqft_lot', 'zipcode', 'lat'),
#  ('sqft_lot', 'zipcode', 'long'),
#  ('sqft_lot', 'zipcode', 'sqft_living15'),
#  ('sqft_lot', 'zipcode', 'sqft_lot15'),
#  ('sqft_lot', 'lat', 'long'),
#  ('sqft_lot', 'lat', 'sqft_living15'),
#  ('sqft_lot', 'lat', 'sqft_lot15'),
#  ('sqft_lot', 'long', 'sqft_living15'),
#  ('sqft_lot', 'long', 'sqft_lot15'),
#  ('sqft_lot', 'sqft_living15', 'sqft_lot15'),
#  ('floors', 'waterfront', 'view'),
#  ('floors', 'waterfront', 'condition'),
#  ('floors', 'waterfront', 'grade'),
#  ('floors', 'waterfront', 'sqft_above'),
#  ('floors', 'waterfront', 'sqft_basement'),
#  ('floors', 'waterfront', 'yr_built'),
#  ('floors', 'waterfront', 'yr_renovated'),
#  ('floors', 'waterfront', 'zipcode'),
#  ('floors', 'waterfront', 'lat'),
#  ('floors', 'waterfront', 'long'),
#  ('floors', 'waterfront', 'sqft_living15'),
#  ('floors', 'waterfront', 'sqft_lot15'),
#  ('floors', 'view', 'condition'),
#  ('floors', 'view', 'grade'),
#  ('floors', 'view', 'sqft_above'),
#  ('floors', 'view', 'sqft_basement'),
#  ('floors', 'view', 'yr_built'),
#  ('floors', 'view', 'yr_renovated'),
#  ('floors', 'view', 'zipcode'),
#  ('floors', 'view', 'lat'),
#  ('floors', 'view', 'long'),
#  ('floors', 'view', 'sqft_living15'),
#  ('floors', 'view', 'sqft_lot15'),
#  ('floors', 'condition', 'grade'),
#  ('floors', 'condition', 'sqft_above'),
#  ('floors', 'condition', 'sqft_basement'),
#  ('floors', 'condition', 'yr_built'),
#  ('floors', 'condition', 'yr_renovated'),
#  ('floors', 'condition', 'zipcode'),
#  ('floors', 'condition', 'lat'),
#  ('floors', 'condition', 'long'),
#  ('floors', 'condition', 'sqft_living15'),
#  ('floors', 'condition', 'sqft_lot15'),
#  ('floors', 'grade', 'sqft_above'),
#  ('floors', 'grade', 'sqft_basement'),
#  ('floors', 'grade', 'yr_built'),
#  ('floors', 'grade', 'yr_renovated'),
#  ('floors', 'grade', 'zipcode'),
#  ('floors', 'grade', 'lat'),
#  ('floors', 'grade', 'long'),
#  ('floors', 'grade', 'sqft_living15'),
#  ('floors', 'grade', 'sqft_lot15'),
#  ('floors', 'sqft_above', 'sqft_basement'),
#  ('floors', 'sqft_above', 'yr_built'),
#  ('floors', 'sqft_above', 'yr_renovated'),
#  ('floors', 'sqft_above', 'zipcode'),
#  ('floors', 'sqft_above', 'lat'),
#  ('floors', 'sqft_above', 'long'),
#  ('floors', 'sqft_above', 'sqft_living15'),
#  ('floors', 'sqft_above', 'sqft_lot15'),
#  ('floors', 'sqft_basement', 'yr_built'),
#  ('floors', 'sqft_basement', 'yr_renovated'),
#  ('floors', 'sqft_basement', 'zipcode'),
#  ('floors', 'sqft_basement', 'lat'),
#  ('floors', 'sqft_basement', 'long'),
#  ('floors', 'sqft_basement', 'sqft_living15'),
#  ('floors', 'sqft_basement', 'sqft_lot15'),
#  ('floors', 'yr_built', 'yr_renovated'),
#  ('floors', 'yr_built', 'zipcode'),
#  ('floors', 'yr_built', 'lat'),
#  ('floors', 'yr_built', 'long'),
#  ('floors', 'yr_built', 'sqft_living15'),
#  ('floors', 'yr_built', 'sqft_lot15'),
#  ('floors', 'yr_renovated', 'zipcode'),
#  ('floors', 'yr_renovated', 'lat'),
#  ('floors', 'yr_renovated', 'long'),
#  ('floors', 'yr_renovated', 'sqft_living15'),
#  ('floors', 'yr_renovated', 'sqft_lot15'),
#  ('floors', 'zipcode', 'lat'),
#  ('floors', 'zipcode', 'long'),
#  ('floors', 'zipcode', 'sqft_living15'),
#  ('floors', 'zipcode', 'sqft_lot15'),
#  ('floors', 'lat', 'long'),
#  ('floors', 'lat', 'sqft_living15'),
#  ('floors', 'lat', 'sqft_lot15'),
#  ('floors', 'long', 'sqft_living15'),
#  ('floors', 'long', 'sqft_lot15'),
#  ('floors', 'sqft_living15', 'sqft_lot15'),
#  ('waterfront', 'view', 'condition'),
#  ('waterfront', 'view', 'grade'),
#  ('waterfront', 'view', 'sqft_above'),
#  ('waterfront', 'view', 'sqft_basement'),
#  ('waterfront', 'view', 'yr_built'),
#  ('waterfront', 'view', 'yr_renovated'),
#  ('waterfront', 'view', 'zipcode'),
#  ('waterfront', 'view', 'lat'),
#  ('waterfront', 'view', 'long'),
#  ('waterfront', 'view', 'sqft_living15'),
#  ('waterfront', 'view', 'sqft_lot15'),
#  ('waterfront', 'condition', 'grade'),
#  ('waterfront', 'condition', 'sqft_above'),
#  ('waterfront', 'condition', 'sqft_basement'),
#  ('waterfront', 'condition', 'yr_built'),
#  ('waterfront', 'condition', 'yr_renovated'),
#  ('waterfront', 'condition', 'zipcode'),
#  ('waterfront', 'condition', 'lat'),
#  ('waterfront', 'condition', 'long'),
#  ('waterfront', 'condition', 'sqft_living15'),
#  ('waterfront', 'condition', 'sqft_lot15'),
#  ('waterfront', 'grade', 'sqft_above'),
#  ('waterfront', 'grade', 'sqft_basement'),
#  ('waterfront', 'grade', 'yr_built'),
#  ('waterfront', 'grade', 'yr_renovated'),
#  ('waterfront', 'grade', 'zipcode'),
#  ('waterfront', 'grade', 'lat'),
#  ('waterfront', 'grade', 'long'),
#  ('waterfront', 'grade', 'sqft_living15'),
#  ('waterfront', 'grade', 'sqft_lot15'),
#  ('waterfront', 'sqft_above', 'sqft_basement'),
#  ('waterfront', 'sqft_above', 'yr_built'),
#  ('waterfront', 'sqft_above', 'yr_renovated'),
#  ('waterfront', 'sqft_above', 'zipcode'),
#  ('waterfront', 'sqft_above', 'lat'),
#  ('waterfront', 'sqft_above', 'long'),
#  ('waterfront', 'sqft_above', 'sqft_living15'),
#  ('waterfront', 'sqft_above', 'sqft_lot15'),
#  ('waterfront', 'sqft_basement', 'yr_built'),
#  ('waterfront', 'sqft_basement', 'yr_renovated'),
#  ('waterfront', 'sqft_basement', 'zipcode'),
#  ('waterfront', 'sqft_basement', 'lat'),
#  ('waterfront', 'sqft_basement', 'long'),
#  ('waterfront', 'sqft_basement', 'sqft_living15'),
#  ('waterfront', 'sqft_basement', 'sqft_lot15'),
#  ('waterfront', 'yr_built', 'yr_renovated'),
#  ('waterfront', 'yr_built', 'zipcode'),
#  ('waterfront', 'yr_built', 'lat'),
#  ('waterfront', 'yr_built', 'long'),
#  ('waterfront', 'yr_built', 'sqft_living15'),
#  ('waterfront', 'yr_built', 'sqft_lot15'),
#  ('waterfront', 'yr_renovated', 'zipcode'),
#  ('waterfront', 'yr_renovated', 'lat'),
#  ('waterfront', 'yr_renovated', 'long'),
#  ('waterfront', 'yr_renovated', 'sqft_living15'),
#  ('waterfront', 'yr_renovated', 'sqft_lot15'),
#  ('waterfront', 'zipcode', 'lat'),
#  ('waterfront', 'zipcode', 'long'),
#  ('waterfront', 'zipcode', 'sqft_living15'),
#  ('waterfront', 'zipcode', 'sqft_lot15'),
#  ('waterfront', 'lat', 'long'),
#  ('waterfront', 'lat', 'sqft_living15'),
#  ('waterfront', 'lat', 'sqft_lot15'),
#  ('waterfront', 'long', 'sqft_living15'),
#  ('waterfront', 'long', 'sqft_lot15'),
#  ('waterfront', 'sqft_living15', 'sqft_lot15'),
#  ('view', 'condition', 'grade'),
#  ('view', 'condition', 'sqft_above'),
#  ('view', 'condition', 'sqft_basement'),
#  ('view', 'condition', 'yr_built'),
#  ('view', 'condition', 'yr_renovated'),
#  ('view', 'condition', 'zipcode'),
#  ('view', 'condition', 'lat'),
#  ('view', 'condition', 'long'),
#  ('view', 'condition', 'sqft_living15'),
#  ('view', 'condition', 'sqft_lot15'),
#  ('view', 'grade', 'sqft_above'),
#  ('view', 'grade', 'sqft_basement'),
#  ('view', 'grade', 'yr_built'),
#  ('view', 'grade', 'yr_renovated'),
#  ('view', 'grade', 'zipcode'),
#  ('view', 'grade', 'lat'),
#  ('view', 'grade', 'long'),
#  ('view', 'grade', 'sqft_living15'),
#  ('view', 'grade', 'sqft_lot15'),
#  ('view', 'sqft_above', 'sqft_basement'),
#  ('view', 'sqft_above', 'yr_built'),
#  ('view', 'sqft_above', 'yr_renovated'),
#  ('view', 'sqft_above', 'zipcode'),
#  ('view', 'sqft_above', 'lat'),
#  ('view', 'sqft_above', 'long'),
#  ('view', 'sqft_above', 'sqft_living15'),
#  ('view', 'sqft_above', 'sqft_lot15'),
#  ('view', 'sqft_basement', 'yr_built'),
#  ('view', 'sqft_basement', 'yr_renovated'),
#  ('view', 'sqft_basement', 'zipcode'),
#  ('view', 'sqft_basement', 'lat'),
#  ('view', 'sqft_basement', 'long'),
#  ('view', 'sqft_basement', 'sqft_living15'),
#  ('view', 'sqft_basement', 'sqft_lot15'),
#  ('view', 'yr_built', 'yr_renovated'),
#  ('view', 'yr_built', 'zipcode'),
#  ('view', 'yr_built', 'lat'),
#  ('view', 'yr_built', 'long'),
#  ('view', 'yr_built', 'sqft_living15'),
#  ('view', 'yr_built', 'sqft_lot15'),
#  ('view', 'yr_renovated', 'zipcode'),
#  ('view', 'yr_renovated', 'lat'),
#  ('view', 'yr_renovated', 'long'),
#  ('view', 'yr_renovated', 'sqft_living15'),
#  ('view', 'yr_renovated', 'sqft_lot15'),
#  ('view', 'zipcode', 'lat'),
#  ('view', 'zipcode', 'long'),
#  ('view', 'zipcode', 'sqft_living15'),
#  ('view', 'zipcode', 'sqft_lot15'),
#  ('view', 'lat', 'long'),
#  ('view', 'lat', 'sqft_living15'),
#  ('view', 'lat', 'sqft_lot15'),
#  ('view', 'long', 'sqft_living15'),
#  ('view', 'long', 'sqft_lot15'),
#  ('view', 'sqft_living15', 'sqft_lot15'),
#  ('condition', 'grade', 'sqft_above'),
#  ('condition', 'grade', 'sqft_basement'),
#  ('condition', 'grade', 'yr_built'),
#  ('condition', 'grade', 'yr_renovated'),
#  ('condition', 'grade', 'zipcode'),
#  ('condition', 'grade', 'lat'),
#  ('condition', 'grade', 'long'),
#  ('condition', 'grade', 'sqft_living15'),
#  ('condition', 'grade', 'sqft_lot15'),
#  ('condition', 'sqft_above', 'sqft_basement'),
#  ('condition', 'sqft_above', 'yr_built'),
#  ('condition', 'sqft_above', 'yr_renovated'),
#  ('condition', 'sqft_above', 'zipcode'),
#  ('condition', 'sqft_above', 'lat'),
#  ('condition', 'sqft_above', 'long'),
#  ('condition', 'sqft_above', 'sqft_living15'),
#  ('condition', 'sqft_above', 'sqft_lot15'),
#  ('condition', 'sqft_basement', 'yr_built'),
#  ('condition', 'sqft_basement', 'yr_renovated'),
#  ('condition', 'sqft_basement', 'zipcode'),
#  ('condition', 'sqft_basement', 'lat'),
#  ('condition', 'sqft_basement', 'long'),
#  ('condition', 'sqft_basement', 'sqft_living15'),
#  ('condition', 'sqft_basement', 'sqft_lot15'),
#  ('condition', 'yr_built', 'yr_renovated'),
#  ('condition', 'yr_built', 'zipcode'),
#  ('condition', 'yr_built', 'lat'),
#  ('condition', 'yr_built', 'long'),
#  ('condition', 'yr_built', 'sqft_living15'),
#  ('condition', 'yr_built', 'sqft_lot15'),
#  ('condition', 'yr_renovated', 'zipcode'),
#  ('condition', 'yr_renovated', 'lat'),
#  ('condition', 'yr_renovated', 'long'),
#  ('condition', 'yr_renovated', 'sqft_living15'),
#  ('condition', 'yr_renovated', 'sqft_lot15'),
#  ('condition', 'zipcode', 'lat'),
#  ('condition', 'zipcode', 'long'),
#  ('condition', 'zipcode', 'sqft_living15'),
#  ('condition', 'zipcode', 'sqft_lot15'),
#  ('condition', 'lat', 'long'),
#  ('condition', 'lat', 'sqft_living15'),
#  ('condition', 'lat', 'sqft_lot15'),
#  ('condition', 'long', 'sqft_living15'),
#  ('condition', 'long', 'sqft_lot15'),
#  ('condition', 'sqft_living15', 'sqft_lot15'),
#  ('grade', 'sqft_above', 'sqft_basement'),
#  ('grade', 'sqft_above', 'yr_built'),
#  ('grade', 'sqft_above', 'yr_renovated'),
#  ('grade', 'sqft_above', 'zipcode'),
#  ('grade', 'sqft_above', 'lat'),
#  ('grade', 'sqft_above', 'long'),
#  ('grade', 'sqft_above', 'sqft_living15'),
#  ('grade', 'sqft_above', 'sqft_lot15'),
#  ('grade', 'sqft_basement', 'yr_built'),
#  ('grade', 'sqft_basement', 'yr_renovated'),
#  ('grade', 'sqft_basement', 'zipcode'),
#  ('grade', 'sqft_basement', 'lat'),
#  ('grade', 'sqft_basement', 'long'),
#  ('grade', 'sqft_basement', 'sqft_living15'),
#  ('grade', 'sqft_basement', 'sqft_lot15'),
#  ('grade', 'yr_built', 'yr_renovated'),
#  ('grade', 'yr_built', 'zipcode'),
#  ('grade', 'yr_built', 'lat'),
#  ('grade', 'yr_built', 'long'),
#  ('grade', 'yr_built', 'sqft_living15'),
#  ('grade', 'yr_built', 'sqft_lot15'),
#  ('grade', 'yr_renovated', 'zipcode'),
#  ('grade', 'yr_renovated', 'lat'),
#  ('grade', 'yr_renovated', 'long'),
#  ('grade', 'yr_renovated', 'sqft_living15'),
#  ('grade', 'yr_renovated', 'sqft_lot15'),
#  ('grade', 'zipcode', 'lat'),
#  ('grade', 'zipcode', 'long'),
#  ('grade', 'zipcode', 'sqft_living15'),
#  ('grade', 'zipcode', 'sqft_lot15'),
#  ('grade', 'lat', 'long'),
#  ('grade', 'lat', 'sqft_living15'),
#  ('grade', 'lat', 'sqft_lot15'),
#  ('grade', 'long', 'sqft_living15'),
#  ('grade', 'long', 'sqft_lot15'),
#  ('grade', 'sqft_living15', 'sqft_lot15'),
#  ('sqft_above', 'sqft_basement', 'yr_built'),
#  ('sqft_above', 'sqft_basement', 'yr_renovated'),
#  ('sqft_above', 'sqft_basement', 'zipcode'),
#  ('sqft_above', 'sqft_basement', 'lat'),
#  ('sqft_above', 'sqft_basement', 'long'),
#  ('sqft_above', 'sqft_basement', 'sqft_living15'),
#  ('sqft_above', 'sqft_basement', 'sqft_lot15'),
#  ('sqft_above', 'yr_built', 'yr_renovated'),
#  ('sqft_above', 'yr_built', 'zipcode'),
#  ('sqft_above', 'yr_built', 'lat'),
#  ('sqft_above', 'yr_built', 'long'),
#  ('sqft_above', 'yr_built', 'sqft_living15'),
#  ('sqft_above', 'yr_built', 'sqft_lot15'),
#  ('sqft_above', 'yr_renovated', 'zipcode'),
#  ('sqft_above', 'yr_renovated', 'lat'),
#  ('sqft_above', 'yr_renovated', 'long'),
#  ('sqft_above', 'yr_renovated', 'sqft_living15'),
#  ('sqft_above', 'yr_renovated', 'sqft_lot15'),
#  ('sqft_above', 'zipcode', 'lat'),
#  ('sqft_above', 'zipcode', 'long'),
#  ('sqft_above', 'zipcode', 'sqft_living15'),
#  ('sqft_above', 'zipcode', 'sqft_lot15'),
#  ('sqft_above', 'lat', 'long'),
#  ('sqft_above', 'lat', 'sqft_living15'),
#  ('sqft_above', 'lat', 'sqft_lot15'),
#  ('sqft_above', 'long', 'sqft_living15'),
#  ('sqft_above', 'long', 'sqft_lot15'),
#  ('sqft_above', 'sqft_living15', 'sqft_lot15'),
#  ('sqft_basement', 'yr_built', 'yr_renovated'),
#  ('sqft_basement', 'yr_built', 'zipcode'),
#  ('sqft_basement', 'yr_built', 'lat'),
#  ('sqft_basement', 'yr_built', 'long'),
#  ('sqft_basement', 'yr_built', 'sqft_living15'),
#  ('sqft_basement', 'yr_built', 'sqft_lot15'),
#  ('sqft_basement', 'yr_renovated', 'zipcode'),
#  ('sqft_basement', 'yr_renovated', 'lat'),
#  ('sqft_basement', 'yr_renovated', 'long'),
#  ('sqft_basement', 'yr_renovated', 'sqft_living15'),
#  ('sqft_basement', 'yr_renovated', 'sqft_lot15'),
#  ('sqft_basement', 'zipcode', 'lat'),
#  ('sqft_basement', 'zipcode', 'long'),
#  ('sqft_basement', 'zipcode', 'sqft_living15'),
#  ('sqft_basement', 'zipcode', 'sqft_lot15'),
#  ('sqft_basement', 'lat', 'long'),
#  ('sqft_basement', 'lat', 'sqft_living15'),
#  ('sqft_basement', 'lat', 'sqft_lot15'),
#  ('sqft_basement', 'long', 'sqft_living15'),
#  ('sqft_basement', 'long', 'sqft_lot15'),
#  ('sqft_basement', 'sqft_living15', 'sqft_lot15'),
#  ('yr_built', 'yr_renovated', 'zipcode'),
#  ('yr_built', 'yr_renovated', 'lat'),
#  ('yr_built', 'yr_renovated', 'long'),
#  ('yr_built', 'yr_renovated', 'sqft_living15'),
#  ('yr_built', 'yr_renovated', 'sqft_lot15'),
#  ('yr_built', 'zipcode', 'lat'),
#  ('yr_built', 'zipcode', 'long'),
#  ('yr_built', 'zipcode', 'sqft_living15'),
#  ('yr_built', 'zipcode', 'sqft_lot15'),
#  ('yr_built', 'lat', 'long'),
#  ('yr_built', 'lat', 'sqft_living15'),
#  ('yr_built', 'lat', 'sqft_lot15'),
#  ('yr_built', 'long', 'sqft_living15'),
#  ('yr_built', 'long', 'sqft_lot15'),
#  ('yr_built', 'sqft_living15', 'sqft_lot15'),
#  ('yr_renovated', 'zipcode', 'lat'),
#  ('yr_renovated', 'zipcode', 'long'),
#  ('yr_renovated', 'zipcode', 'sqft_living15'),
#  ('yr_renovated', 'zipcode', 'sqft_lot15'),
#  ('yr_renovated', 'lat', 'long'),
#  ('yr_renovated', 'lat', 'sqft_living15'),
#  ('yr_renovated', 'lat', 'sqft_lot15'),
#  ('yr_renovated', 'long', 'sqft_living15'),
#  ('yr_renovated', 'long', 'sqft_lot15'),
#  ('yr_renovated', 'sqft_living15', 'sqft_lot15'),
#  ('zipcode', 'lat', 'long'),
#  ('zipcode', 'lat', 'sqft_living15'),
#  ('zipcode', 'lat', 'sqft_lot15'),
#  ('zipcode', 'long', 'sqft_living15'),
#  ('zipcode', 'long', 'sqft_lot15'),
#  ('zipcode', 'sqft_living15', 'sqft_lot15'),
#  ('lat', 'long', 'sqft_living15'),
#  ('lat', 'long', 'sqft_lot15'),
#  ('lat', 'sqft_living15', 'sqft_lot15'),
#  ('long', 'sqft_living15', 'sqft_lot15'),
#  ('bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot'),
#  ('bedrooms', 'bathrooms', 'sqft_living', 'floors'),
#  ('bedrooms', 'bathrooms', 'sqft_living', 'waterfront'),
#  ('bedrooms', 'bathrooms', 'sqft_living', 'view'),
#  ('bedrooms', 'bathrooms', 'sqft_living', 'condition'),
#  ('bedrooms', 'bathrooms', 'sqft_living', 'grade'),
#  ('bedrooms', 'bathrooms', 'sqft_living', 'sqft_above'),
#  ('bedrooms', 'bathrooms', 'sqft_living', 'sqft_basement'),
#  ('bedrooms', 'bathrooms', 'sqft_living', 'yr_built'),
#  ('bedrooms', 'bathrooms', 'sqft_living', 'yr_renovated'),
#  ('bedrooms', 'bathrooms', 'sqft_living', 'zipcode'),
#  ('bedrooms', 'bathrooms', 'sqft_living', 'lat'),
#  ...]

# %%
feature_list.pop(0)
# Out:
# ()

# %%
len(feature_list)
# Out:
# 262143

# %%
feature_list = [list(elem) for elem in feature_list]
feature_list
# Out:
# [['bedrooms'],
#  ['bathrooms'],
#  ['sqft_living'],
#  ['sqft_lot'],
#  ['floors'],
#  ['waterfront'],
#  ['view'],
#  ['condition'],
#  ['grade'],
#  ['sqft_above'],
#  ['sqft_basement'],
#  ['yr_built'],
#  ['yr_renovated'],
#  ['zipcode'],
#  ['lat'],
#  ['long'],
#  ['sqft_living15'],
#  ['sqft_lot15'],
#  ['bedrooms', 'bathrooms'],
#  ['bedrooms', 'sqft_living'],
#  ['bedrooms', 'sqft_lot'],
#  ['bedrooms', 'floors'],
#  ['bedrooms', 'waterfront'],
#  ['bedrooms', 'view'],
#  ['bedrooms', 'condition'],
#  ['bedrooms', 'grade'],
#  ['bedrooms', 'sqft_above'],
#  ['bedrooms', 'sqft_basement'],
#  ['bedrooms', 'yr_built'],
#  ['bedrooms', 'yr_renovated'],
#  ['bedrooms', 'zipcode'],
#  ['bedrooms', 'lat'],
#  ['bedrooms', 'long'],
#  ['bedrooms', 'sqft_living15'],
#  ['bedrooms', 'sqft_lot15'],
#  ['bathrooms', 'sqft_living'],
#  ['bathrooms', 'sqft_lot'],
#  ['bathrooms', 'floors'],
#  ['bathrooms', 'waterfront'],
#  ['bathrooms', 'view'],
#  ['bathrooms', 'condition'],
#  ['bathrooms', 'grade'],
#  ['bathrooms', 'sqft_above'],
#  ['bathrooms', 'sqft_basement'],
#  ['bathrooms', 'yr_built'],
#  ['bathrooms', 'yr_renovated'],
#  ['bathrooms', 'zipcode'],
#  ['bathrooms', 'lat'],
#  ['bathrooms', 'long'],
#  ['bathrooms', 'sqft_living15'],
#  ['bathrooms', 'sqft_lot15'],
#  ['sqft_living', 'sqft_lot'],
#  ['sqft_living', 'floors'],
#  ['sqft_living', 'waterfront'],
#  ['sqft_living', 'view'],
#  ['sqft_living', 'condition'],
#  ['sqft_living', 'grade'],
#  ['sqft_living', 'sqft_above'],
#  ['sqft_living', 'sqft_basement'],
#  ['sqft_living', 'yr_built'],
#  ['sqft_living', 'yr_renovated'],
#  ['sqft_living', 'zipcode'],
#  ['sqft_living', 'lat'],
#  ['sqft_living', 'long'],
#  ['sqft_living', 'sqft_living15'],
#  ['sqft_living', 'sqft_lot15'],
#  ['sqft_lot', 'floors'],
#  ['sqft_lot', 'waterfront'],
#  ['sqft_lot', 'view'],
#  ['sqft_lot', 'condition'],
#  ['sqft_lot', 'grade'],
#  ['sqft_lot', 'sqft_above'],
#  ['sqft_lot', 'sqft_basement'],
#  ['sqft_lot', 'yr_built'],
#  ['sqft_lot', 'yr_renovated'],
#  ['sqft_lot', 'zipcode'],
#  ['sqft_lot', 'lat'],
#  ['sqft_lot', 'long'],
#  ['sqft_lot', 'sqft_living15'],
#  ['sqft_lot', 'sqft_lot15'],
#  ['floors', 'waterfront'],
#  ['floors', 'view'],
#  ['floors', 'condition'],
#  ['floors', 'grade'],
#  ['floors', 'sqft_above'],
#  ['floors', 'sqft_basement'],
#  ['floors', 'yr_built'],
#  ['floors', 'yr_renovated'],
#  ['floors', 'zipcode'],
#  ['floors', 'lat'],
#  ['floors', 'long'],
#  ['floors', 'sqft_living15'],
#  ['floors', 'sqft_lot15'],
#  ['waterfront', 'view'],
#  ['waterfront', 'condition'],
#  ['waterfront', 'grade'],
#  ['waterfront', 'sqft_above'],
#  ['waterfront', 'sqft_basement'],
#  ['waterfront', 'yr_built'],
#  ['waterfront', 'yr_renovated'],
#  ['waterfront', 'zipcode'],
#  ['waterfront', 'lat'],
#  ['waterfront', 'long'],
#  ['waterfront', 'sqft_living15'],
#  ['waterfront', 'sqft_lot15'],
#  ['view', 'condition'],
#  ['view', 'grade'],
#  ['view', 'sqft_above'],
#  ['view', 'sqft_basement'],
#  ['view', 'yr_built'],
#  ['view', 'yr_renovated'],
#  ['view', 'zipcode'],
#  ['view', 'lat'],
#  ['view', 'long'],
#  ['view', 'sqft_living15'],
#  ['view', 'sqft_lot15'],
#  ['condition', 'grade'],
#  ['condition', 'sqft_above'],
#  ['condition', 'sqft_basement'],
#  ['condition', 'yr_built'],
#  ['condition', 'yr_renovated'],
#  ['condition', 'zipcode'],
#  ['condition', 'lat'],
#  ['condition', 'long'],
#  ['condition', 'sqft_living15'],
#  ['condition', 'sqft_lot15'],
#  ['grade', 'sqft_above'],
#  ['grade', 'sqft_basement'],
#  ['grade', 'yr_built'],
#  ['grade', 'yr_renovated'],
#  ['grade', 'zipcode'],
#  ['grade', 'lat'],
#  ['grade', 'long'],
#  ['grade', 'sqft_living15'],
#  ['grade', 'sqft_lot15'],
#  ['sqft_above', 'sqft_basement'],
#  ['sqft_above', 'yr_built'],
#  ['sqft_above', 'yr_renovated'],
#  ['sqft_above', 'zipcode'],
#  ['sqft_above', 'lat'],
#  ['sqft_above', 'long'],
#  ['sqft_above', 'sqft_living15'],
#  ['sqft_above', 'sqft_lot15'],
#  ['sqft_basement', 'yr_built'],
#  ['sqft_basement', 'yr_renovated'],
#  ['sqft_basement', 'zipcode'],
#  ['sqft_basement', 'lat'],
#  ['sqft_basement', 'long'],
#  ['sqft_basement', 'sqft_living15'],
#  ['sqft_basement', 'sqft_lot15'],
#  ['yr_built', 'yr_renovated'],
#  ['yr_built', 'zipcode'],
#  ['yr_built', 'lat'],
#  ['yr_built', 'long'],
#  ['yr_built', 'sqft_living15'],
#  ['yr_built', 'sqft_lot15'],
#  ['yr_renovated', 'zipcode'],
#  ['yr_renovated', 'lat'],
#  ['yr_renovated', 'long'],
#  ['yr_renovated', 'sqft_living15'],
#  ['yr_renovated', 'sqft_lot15'],
#  ['zipcode', 'lat'],
#  ['zipcode', 'long'],
#  ['zipcode', 'sqft_living15'],
#  ['zipcode', 'sqft_lot15'],
#  ['lat', 'long'],
#  ['lat', 'sqft_living15'],
#  ['lat', 'sqft_lot15'],
#  ['long', 'sqft_living15'],
#  ['long', 'sqft_lot15'],
#  ['sqft_living15', 'sqft_lot15'],
#  ['bedrooms', 'bathrooms', 'sqft_living'],
#  ['bedrooms', 'bathrooms', 'sqft_lot'],
#  ['bedrooms', 'bathrooms', 'floors'],
#  ['bedrooms', 'bathrooms', 'waterfront'],
#  ['bedrooms', 'bathrooms', 'view'],
#  ['bedrooms', 'bathrooms', 'condition'],
#  ['bedrooms', 'bathrooms', 'grade'],
#  ['bedrooms', 'bathrooms', 'sqft_above'],
#  ['bedrooms', 'bathrooms', 'sqft_basement'],
#  ['bedrooms', 'bathrooms', 'yr_built'],
#  ['bedrooms', 'bathrooms', 'yr_renovated'],
#  ['bedrooms', 'bathrooms', 'zipcode'],
#  ['bedrooms', 'bathrooms', 'lat'],
#  ['bedrooms', 'bathrooms', 'long'],
#  ['bedrooms', 'bathrooms', 'sqft_living15'],
#  ['bedrooms', 'bathrooms', 'sqft_lot15'],
#  ['bedrooms', 'sqft_living', 'sqft_lot'],
#  ['bedrooms', 'sqft_living', 'floors'],
#  ['bedrooms', 'sqft_living', 'waterfront'],
#  ['bedrooms', 'sqft_living', 'view'],
#  ['bedrooms', 'sqft_living', 'condition'],
#  ['bedrooms', 'sqft_living', 'grade'],
#  ['bedrooms', 'sqft_living', 'sqft_above'],
#  ['bedrooms', 'sqft_living', 'sqft_basement'],
#  ['bedrooms', 'sqft_living', 'yr_built'],
#  ['bedrooms', 'sqft_living', 'yr_renovated'],
#  ['bedrooms', 'sqft_living', 'zipcode'],
#  ['bedrooms', 'sqft_living', 'lat'],
#  ['bedrooms', 'sqft_living', 'long'],
#  ['bedrooms', 'sqft_living', 'sqft_living15'],
#  ['bedrooms', 'sqft_living', 'sqft_lot15'],
#  ['bedrooms', 'sqft_lot', 'floors'],
#  ['bedrooms', 'sqft_lot', 'waterfront'],
#  ['bedrooms', 'sqft_lot', 'view'],
#  ['bedrooms', 'sqft_lot', 'condition'],
#  ['bedrooms', 'sqft_lot', 'grade'],
#  ['bedrooms', 'sqft_lot', 'sqft_above'],
#  ['bedrooms', 'sqft_lot', 'sqft_basement'],
#  ['bedrooms', 'sqft_lot', 'yr_built'],
#  ['bedrooms', 'sqft_lot', 'yr_renovated'],
#  ['bedrooms', 'sqft_lot', 'zipcode'],
#  ['bedrooms', 'sqft_lot', 'lat'],
#  ['bedrooms', 'sqft_lot', 'long'],
#  ['bedrooms', 'sqft_lot', 'sqft_living15'],
#  ['bedrooms', 'sqft_lot', 'sqft_lot15'],
#  ['bedrooms', 'floors', 'waterfront'],
#  ['bedrooms', 'floors', 'view'],
#  ['bedrooms', 'floors', 'condition'],
#  ['bedrooms', 'floors', 'grade'],
#  ['bedrooms', 'floors', 'sqft_above'],
#  ['bedrooms', 'floors', 'sqft_basement'],
#  ['bedrooms', 'floors', 'yr_built'],
#  ['bedrooms', 'floors', 'yr_renovated'],
#  ['bedrooms', 'floors', 'zipcode'],
#  ['bedrooms', 'floors', 'lat'],
#  ['bedrooms', 'floors', 'long'],
#  ['bedrooms', 'floors', 'sqft_living15'],
#  ['bedrooms', 'floors', 'sqft_lot15'],
#  ['bedrooms', 'waterfront', 'view'],
#  ['bedrooms', 'waterfront', 'condition'],
#  ['bedrooms', 'waterfront', 'grade'],
#  ['bedrooms', 'waterfront', 'sqft_above'],
#  ['bedrooms', 'waterfront', 'sqft_basement'],
#  ['bedrooms', 'waterfront', 'yr_built'],
#  ['bedrooms', 'waterfront', 'yr_renovated'],
#  ['bedrooms', 'waterfront', 'zipcode'],
#  ['bedrooms', 'waterfront', 'lat'],
#  ['bedrooms', 'waterfront', 'long'],
#  ['bedrooms', 'waterfront', 'sqft_living15'],
#  ['bedrooms', 'waterfront', 'sqft_lot15'],
#  ['bedrooms', 'view', 'condition'],
#  ['bedrooms', 'view', 'grade'],
#  ['bedrooms', 'view', 'sqft_above'],
#  ['bedrooms', 'view', 'sqft_basement'],
#  ['bedrooms', 'view', 'yr_built'],
#  ['bedrooms', 'view', 'yr_renovated'],
#  ['bedrooms', 'view', 'zipcode'],
#  ['bedrooms', 'view', 'lat'],
#  ['bedrooms', 'view', 'long'],
#  ['bedrooms', 'view', 'sqft_living15'],
#  ['bedrooms', 'view', 'sqft_lot15'],
#  ['bedrooms', 'condition', 'grade'],
#  ['bedrooms', 'condition', 'sqft_above'],
#  ['bedrooms', 'condition', 'sqft_basement'],
#  ['bedrooms', 'condition', 'yr_built'],
#  ['bedrooms', 'condition', 'yr_renovated'],
#  ['bedrooms', 'condition', 'zipcode'],
#  ['bedrooms', 'condition', 'lat'],
#  ['bedrooms', 'condition', 'long'],
#  ['bedrooms', 'condition', 'sqft_living15'],
#  ['bedrooms', 'condition', 'sqft_lot15'],
#  ['bedrooms', 'grade', 'sqft_above'],
#  ['bedrooms', 'grade', 'sqft_basement'],
#  ['bedrooms', 'grade', 'yr_built'],
#  ['bedrooms', 'grade', 'yr_renovated'],
#  ['bedrooms', 'grade', 'zipcode'],
#  ['bedrooms', 'grade', 'lat'],
#  ['bedrooms', 'grade', 'long'],
#  ['bedrooms', 'grade', 'sqft_living15'],
#  ['bedrooms', 'grade', 'sqft_lot15'],
#  ['bedrooms', 'sqft_above', 'sqft_basement'],
#  ['bedrooms', 'sqft_above', 'yr_built'],
#  ['bedrooms', 'sqft_above', 'yr_renovated'],
#  ['bedrooms', 'sqft_above', 'zipcode'],
#  ['bedrooms', 'sqft_above', 'lat'],
#  ['bedrooms', 'sqft_above', 'long'],
#  ['bedrooms', 'sqft_above', 'sqft_living15'],
#  ['bedrooms', 'sqft_above', 'sqft_lot15'],
#  ['bedrooms', 'sqft_basement', 'yr_built'],
#  ['bedrooms', 'sqft_basement', 'yr_renovated'],
#  ['bedrooms', 'sqft_basement', 'zipcode'],
#  ['bedrooms', 'sqft_basement', 'lat'],
#  ['bedrooms', 'sqft_basement', 'long'],
#  ['bedrooms', 'sqft_basement', 'sqft_living15'],
#  ['bedrooms', 'sqft_basement', 'sqft_lot15'],
#  ['bedrooms', 'yr_built', 'yr_renovated'],
#  ['bedrooms', 'yr_built', 'zipcode'],
#  ['bedrooms', 'yr_built', 'lat'],
#  ['bedrooms', 'yr_built', 'long'],
#  ['bedrooms', 'yr_built', 'sqft_living15'],
#  ['bedrooms', 'yr_built', 'sqft_lot15'],
#  ['bedrooms', 'yr_renovated', 'zipcode'],
#  ['bedrooms', 'yr_renovated', 'lat'],
#  ['bedrooms', 'yr_renovated', 'long'],
#  ['bedrooms', 'yr_renovated', 'sqft_living15'],
#  ['bedrooms', 'yr_renovated', 'sqft_lot15'],
#  ['bedrooms', 'zipcode', 'lat'],
#  ['bedrooms', 'zipcode', 'long'],
#  ['bedrooms', 'zipcode', 'sqft_living15'],
#  ['bedrooms', 'zipcode', 'sqft_lot15'],
#  ['bedrooms', 'lat', 'long'],
#  ['bedrooms', 'lat', 'sqft_living15'],
#  ['bedrooms', 'lat', 'sqft_lot15'],
#  ['bedrooms', 'long', 'sqft_living15'],
#  ['bedrooms', 'long', 'sqft_lot15'],
#  ['bedrooms', 'sqft_living15', 'sqft_lot15'],
#  ['bathrooms', 'sqft_living', 'sqft_lot'],
#  ['bathrooms', 'sqft_living', 'floors'],
#  ['bathrooms', 'sqft_living', 'waterfront'],
#  ['bathrooms', 'sqft_living', 'view'],
#  ['bathrooms', 'sqft_living', 'condition'],
#  ['bathrooms', 'sqft_living', 'grade'],
#  ['bathrooms', 'sqft_living', 'sqft_above'],
#  ['bathrooms', 'sqft_living', 'sqft_basement'],
#  ['bathrooms', 'sqft_living', 'yr_built'],
#  ['bathrooms', 'sqft_living', 'yr_renovated'],
#  ['bathrooms', 'sqft_living', 'zipcode'],
#  ['bathrooms', 'sqft_living', 'lat'],
#  ['bathrooms', 'sqft_living', 'long'],
#  ['bathrooms', 'sqft_living', 'sqft_living15'],
#  ['bathrooms', 'sqft_living', 'sqft_lot15'],
#  ['bathrooms', 'sqft_lot', 'floors'],
#  ['bathrooms', 'sqft_lot', 'waterfront'],
#  ['bathrooms', 'sqft_lot', 'view'],
#  ['bathrooms', 'sqft_lot', 'condition'],
#  ['bathrooms', 'sqft_lot', 'grade'],
#  ['bathrooms', 'sqft_lot', 'sqft_above'],
#  ['bathrooms', 'sqft_lot', 'sqft_basement'],
#  ['bathrooms', 'sqft_lot', 'yr_built'],
#  ['bathrooms', 'sqft_lot', 'yr_renovated'],
#  ['bathrooms', 'sqft_lot', 'zipcode'],
#  ['bathrooms', 'sqft_lot', 'lat'],
#  ['bathrooms', 'sqft_lot', 'long'],
#  ['bathrooms', 'sqft_lot', 'sqft_living15'],
#  ['bathrooms', 'sqft_lot', 'sqft_lot15'],
#  ['bathrooms', 'floors', 'waterfront'],
#  ['bathrooms', 'floors', 'view'],
#  ['bathrooms', 'floors', 'condition'],
#  ['bathrooms', 'floors', 'grade'],
#  ['bathrooms', 'floors', 'sqft_above'],
#  ['bathrooms', 'floors', 'sqft_basement'],
#  ['bathrooms', 'floors', 'yr_built'],
#  ['bathrooms', 'floors', 'yr_renovated'],
#  ['bathrooms', 'floors', 'zipcode'],
#  ['bathrooms', 'floors', 'lat'],
#  ['bathrooms', 'floors', 'long'],
#  ['bathrooms', 'floors', 'sqft_living15'],
#  ['bathrooms', 'floors', 'sqft_lot15'],
#  ['bathrooms', 'waterfront', 'view'],
#  ['bathrooms', 'waterfront', 'condition'],
#  ['bathrooms', 'waterfront', 'grade'],
#  ['bathrooms', 'waterfront', 'sqft_above'],
#  ['bathrooms', 'waterfront', 'sqft_basement'],
#  ['bathrooms', 'waterfront', 'yr_built'],
#  ['bathrooms', 'waterfront', 'yr_renovated'],
#  ['bathrooms', 'waterfront', 'zipcode'],
#  ['bathrooms', 'waterfront', 'lat'],
#  ['bathrooms', 'waterfront', 'long'],
#  ['bathrooms', 'waterfront', 'sqft_living15'],
#  ['bathrooms', 'waterfront', 'sqft_lot15'],
#  ['bathrooms', 'view', 'condition'],
#  ['bathrooms', 'view', 'grade'],
#  ['bathrooms', 'view', 'sqft_above'],
#  ['bathrooms', 'view', 'sqft_basement'],
#  ['bathrooms', 'view', 'yr_built'],
#  ['bathrooms', 'view', 'yr_renovated'],
#  ['bathrooms', 'view', 'zipcode'],
#  ['bathrooms', 'view', 'lat'],
#  ['bathrooms', 'view', 'long'],
#  ['bathrooms', 'view', 'sqft_living15'],
#  ['bathrooms', 'view', 'sqft_lot15'],
#  ['bathrooms', 'condition', 'grade'],
#  ['bathrooms', 'condition', 'sqft_above'],
#  ['bathrooms', 'condition', 'sqft_basement'],
#  ['bathrooms', 'condition', 'yr_built'],
#  ['bathrooms', 'condition', 'yr_renovated'],
#  ['bathrooms', 'condition', 'zipcode'],
#  ['bathrooms', 'condition', 'lat'],
#  ['bathrooms', 'condition', 'long'],
#  ['bathrooms', 'condition', 'sqft_living15'],
#  ['bathrooms', 'condition', 'sqft_lot15'],
#  ['bathrooms', 'grade', 'sqft_above'],
#  ['bathrooms', 'grade', 'sqft_basement'],
#  ['bathrooms', 'grade', 'yr_built'],
#  ['bathrooms', 'grade', 'yr_renovated'],
#  ['bathrooms', 'grade', 'zipcode'],
#  ['bathrooms', 'grade', 'lat'],
#  ['bathrooms', 'grade', 'long'],
#  ['bathrooms', 'grade', 'sqft_living15'],
#  ['bathrooms', 'grade', 'sqft_lot15'],
#  ['bathrooms', 'sqft_above', 'sqft_basement'],
#  ['bathrooms', 'sqft_above', 'yr_built'],
#  ['bathrooms', 'sqft_above', 'yr_renovated'],
#  ['bathrooms', 'sqft_above', 'zipcode'],
#  ['bathrooms', 'sqft_above', 'lat'],
#  ['bathrooms', 'sqft_above', 'long'],
#  ['bathrooms', 'sqft_above', 'sqft_living15'],
#  ['bathrooms', 'sqft_above', 'sqft_lot15'],
#  ['bathrooms', 'sqft_basement', 'yr_built'],
#  ['bathrooms', 'sqft_basement', 'yr_renovated'],
#  ['bathrooms', 'sqft_basement', 'zipcode'],
#  ['bathrooms', 'sqft_basement', 'lat'],
#  ['bathrooms', 'sqft_basement', 'long'],
#  ['bathrooms', 'sqft_basement', 'sqft_living15'],
#  ['bathrooms', 'sqft_basement', 'sqft_lot15'],
#  ['bathrooms', 'yr_built', 'yr_renovated'],
#  ['bathrooms', 'yr_built', 'zipcode'],
#  ['bathrooms', 'yr_built', 'lat'],
#  ['bathrooms', 'yr_built', 'long'],
#  ['bathrooms', 'yr_built', 'sqft_living15'],
#  ['bathrooms', 'yr_built', 'sqft_lot15'],
#  ['bathrooms', 'yr_renovated', 'zipcode'],
#  ['bathrooms', 'yr_renovated', 'lat'],
#  ['bathrooms', 'yr_renovated', 'long'],
#  ['bathrooms', 'yr_renovated', 'sqft_living15'],
#  ['bathrooms', 'yr_renovated', 'sqft_lot15'],
#  ['bathrooms', 'zipcode', 'lat'],
#  ['bathrooms', 'zipcode', 'long'],
#  ['bathrooms', 'zipcode', 'sqft_living15'],
#  ['bathrooms', 'zipcode', 'sqft_lot15'],
#  ['bathrooms', 'lat', 'long'],
#  ['bathrooms', 'lat', 'sqft_living15'],
#  ['bathrooms', 'lat', 'sqft_lot15'],
#  ['bathrooms', 'long', 'sqft_living15'],
#  ['bathrooms', 'long', 'sqft_lot15'],
#  ['bathrooms', 'sqft_living15', 'sqft_lot15'],
#  ['sqft_living', 'sqft_lot', 'floors'],
#  ['sqft_living', 'sqft_lot', 'waterfront'],
#  ['sqft_living', 'sqft_lot', 'view'],
#  ['sqft_living', 'sqft_lot', 'condition'],
#  ['sqft_living', 'sqft_lot', 'grade'],
#  ['sqft_living', 'sqft_lot', 'sqft_above'],
#  ['sqft_living', 'sqft_lot', 'sqft_basement'],
#  ['sqft_living', 'sqft_lot', 'yr_built'],
#  ['sqft_living', 'sqft_lot', 'yr_renovated'],
#  ['sqft_living', 'sqft_lot', 'zipcode'],
#  ['sqft_living', 'sqft_lot', 'lat'],
#  ['sqft_living', 'sqft_lot', 'long'],
#  ['sqft_living', 'sqft_lot', 'sqft_living15'],
#  ['sqft_living', 'sqft_lot', 'sqft_lot15'],
#  ['sqft_living', 'floors', 'waterfront'],
#  ['sqft_living', 'floors', 'view'],
#  ['sqft_living', 'floors', 'condition'],
#  ['sqft_living', 'floors', 'grade'],
#  ['sqft_living', 'floors', 'sqft_above'],
#  ['sqft_living', 'floors', 'sqft_basement'],
#  ['sqft_living', 'floors', 'yr_built'],
#  ['sqft_living', 'floors', 'yr_renovated'],
#  ['sqft_living', 'floors', 'zipcode'],
#  ['sqft_living', 'floors', 'lat'],
#  ['sqft_living', 'floors', 'long'],
#  ['sqft_living', 'floors', 'sqft_living15'],
#  ['sqft_living', 'floors', 'sqft_lot15'],
#  ['sqft_living', 'waterfront', 'view'],
#  ['sqft_living', 'waterfront', 'condition'],
#  ['sqft_living', 'waterfront', 'grade'],
#  ['sqft_living', 'waterfront', 'sqft_above'],
#  ['sqft_living', 'waterfront', 'sqft_basement'],
#  ['sqft_living', 'waterfront', 'yr_built'],
#  ['sqft_living', 'waterfront', 'yr_renovated'],
#  ['sqft_living', 'waterfront', 'zipcode'],
#  ['sqft_living', 'waterfront', 'lat'],
#  ['sqft_living', 'waterfront', 'long'],
#  ['sqft_living', 'waterfront', 'sqft_living15'],
#  ['sqft_living', 'waterfront', 'sqft_lot15'],
#  ['sqft_living', 'view', 'condition'],
#  ['sqft_living', 'view', 'grade'],
#  ['sqft_living', 'view', 'sqft_above'],
#  ['sqft_living', 'view', 'sqft_basement'],
#  ['sqft_living', 'view', 'yr_built'],
#  ['sqft_living', 'view', 'yr_renovated'],
#  ['sqft_living', 'view', 'zipcode'],
#  ['sqft_living', 'view', 'lat'],
#  ['sqft_living', 'view', 'long'],
#  ['sqft_living', 'view', 'sqft_living15'],
#  ['sqft_living', 'view', 'sqft_lot15'],
#  ['sqft_living', 'condition', 'grade'],
#  ['sqft_living', 'condition', 'sqft_above'],
#  ['sqft_living', 'condition', 'sqft_basement'],
#  ['sqft_living', 'condition', 'yr_built'],
#  ['sqft_living', 'condition', 'yr_renovated'],
#  ['sqft_living', 'condition', 'zipcode'],
#  ['sqft_living', 'condition', 'lat'],
#  ['sqft_living', 'condition', 'long'],
#  ['sqft_living', 'condition', 'sqft_living15'],
#  ['sqft_living', 'condition', 'sqft_lot15'],
#  ['sqft_living', 'grade', 'sqft_above'],
#  ['sqft_living', 'grade', 'sqft_basement'],
#  ['sqft_living', 'grade', 'yr_built'],
#  ['sqft_living', 'grade', 'yr_renovated'],
#  ['sqft_living', 'grade', 'zipcode'],
#  ['sqft_living', 'grade', 'lat'],
#  ['sqft_living', 'grade', 'long'],
#  ['sqft_living', 'grade', 'sqft_living15'],
#  ['sqft_living', 'grade', 'sqft_lot15'],
#  ['sqft_living', 'sqft_above', 'sqft_basement'],
#  ['sqft_living', 'sqft_above', 'yr_built'],
#  ['sqft_living', 'sqft_above', 'yr_renovated'],
#  ['sqft_living', 'sqft_above', 'zipcode'],
#  ['sqft_living', 'sqft_above', 'lat'],
#  ['sqft_living', 'sqft_above', 'long'],
#  ['sqft_living', 'sqft_above', 'sqft_living15'],
#  ['sqft_living', 'sqft_above', 'sqft_lot15'],
#  ['sqft_living', 'sqft_basement', 'yr_built'],
#  ['sqft_living', 'sqft_basement', 'yr_renovated'],
#  ['sqft_living', 'sqft_basement', 'zipcode'],
#  ['sqft_living', 'sqft_basement', 'lat'],
#  ['sqft_living', 'sqft_basement', 'long'],
#  ['sqft_living', 'sqft_basement', 'sqft_living15'],
#  ['sqft_living', 'sqft_basement', 'sqft_lot15'],
#  ['sqft_living', 'yr_built', 'yr_renovated'],
#  ['sqft_living', 'yr_built', 'zipcode'],
#  ['sqft_living', 'yr_built', 'lat'],
#  ['sqft_living', 'yr_built', 'long'],
#  ['sqft_living', 'yr_built', 'sqft_living15'],
#  ['sqft_living', 'yr_built', 'sqft_lot15'],
#  ['sqft_living', 'yr_renovated', 'zipcode'],
#  ['sqft_living', 'yr_renovated', 'lat'],
#  ['sqft_living', 'yr_renovated', 'long'],
#  ['sqft_living', 'yr_renovated', 'sqft_living15'],
#  ['sqft_living', 'yr_renovated', 'sqft_lot15'],
#  ['sqft_living', 'zipcode', 'lat'],
#  ['sqft_living', 'zipcode', 'long'],
#  ['sqft_living', 'zipcode', 'sqft_living15'],
#  ['sqft_living', 'zipcode', 'sqft_lot15'],
#  ['sqft_living', 'lat', 'long'],
#  ['sqft_living', 'lat', 'sqft_living15'],
#  ['sqft_living', 'lat', 'sqft_lot15'],
#  ['sqft_living', 'long', 'sqft_living15'],
#  ['sqft_living', 'long', 'sqft_lot15'],
#  ['sqft_living', 'sqft_living15', 'sqft_lot15'],
#  ['sqft_lot', 'floors', 'waterfront'],
#  ['sqft_lot', 'floors', 'view'],
#  ['sqft_lot', 'floors', 'condition'],
#  ['sqft_lot', 'floors', 'grade'],
#  ['sqft_lot', 'floors', 'sqft_above'],
#  ['sqft_lot', 'floors', 'sqft_basement'],
#  ['sqft_lot', 'floors', 'yr_built'],
#  ['sqft_lot', 'floors', 'yr_renovated'],
#  ['sqft_lot', 'floors', 'zipcode'],
#  ['sqft_lot', 'floors', 'lat'],
#  ['sqft_lot', 'floors', 'long'],
#  ['sqft_lot', 'floors', 'sqft_living15'],
#  ['sqft_lot', 'floors', 'sqft_lot15'],
#  ['sqft_lot', 'waterfront', 'view'],
#  ['sqft_lot', 'waterfront', 'condition'],
#  ['sqft_lot', 'waterfront', 'grade'],
#  ['sqft_lot', 'waterfront', 'sqft_above'],
#  ['sqft_lot', 'waterfront', 'sqft_basement'],
#  ['sqft_lot', 'waterfront', 'yr_built'],
#  ['sqft_lot', 'waterfront', 'yr_renovated'],
#  ['sqft_lot', 'waterfront', 'zipcode'],
#  ['sqft_lot', 'waterfront', 'lat'],
#  ['sqft_lot', 'waterfront', 'long'],
#  ['sqft_lot', 'waterfront', 'sqft_living15'],
#  ['sqft_lot', 'waterfront', 'sqft_lot15'],
#  ['sqft_lot', 'view', 'condition'],
#  ['sqft_lot', 'view', 'grade'],
#  ['sqft_lot', 'view', 'sqft_above'],
#  ['sqft_lot', 'view', 'sqft_basement'],
#  ['sqft_lot', 'view', 'yr_built'],
#  ['sqft_lot', 'view', 'yr_renovated'],
#  ['sqft_lot', 'view', 'zipcode'],
#  ['sqft_lot', 'view', 'lat'],
#  ['sqft_lot', 'view', 'long'],
#  ['sqft_lot', 'view', 'sqft_living15'],
#  ['sqft_lot', 'view', 'sqft_lot15'],
#  ['sqft_lot', 'condition', 'grade'],
#  ['sqft_lot', 'condition', 'sqft_above'],
#  ['sqft_lot', 'condition', 'sqft_basement'],
#  ['sqft_lot', 'condition', 'yr_built'],
#  ['sqft_lot', 'condition', 'yr_renovated'],
#  ['sqft_lot', 'condition', 'zipcode'],
#  ['sqft_lot', 'condition', 'lat'],
#  ['sqft_lot', 'condition', 'long'],
#  ['sqft_lot', 'condition', 'sqft_living15'],
#  ['sqft_lot', 'condition', 'sqft_lot15'],
#  ['sqft_lot', 'grade', 'sqft_above'],
#  ['sqft_lot', 'grade', 'sqft_basement'],
#  ['sqft_lot', 'grade', 'yr_built'],
#  ['sqft_lot', 'grade', 'yr_renovated'],
#  ['sqft_lot', 'grade', 'zipcode'],
#  ['sqft_lot', 'grade', 'lat'],
#  ['sqft_lot', 'grade', 'long'],
#  ['sqft_lot', 'grade', 'sqft_living15'],
#  ['sqft_lot', 'grade', 'sqft_lot15'],
#  ['sqft_lot', 'sqft_above', 'sqft_basement'],
#  ['sqft_lot', 'sqft_above', 'yr_built'],
#  ['sqft_lot', 'sqft_above', 'yr_renovated'],
#  ['sqft_lot', 'sqft_above', 'zipcode'],
#  ['sqft_lot', 'sqft_above', 'lat'],
#  ['sqft_lot', 'sqft_above', 'long'],
#  ['sqft_lot', 'sqft_above', 'sqft_living15'],
#  ['sqft_lot', 'sqft_above', 'sqft_lot15'],
#  ['sqft_lot', 'sqft_basement', 'yr_built'],
#  ['sqft_lot', 'sqft_basement', 'yr_renovated'],
#  ['sqft_lot', 'sqft_basement', 'zipcode'],
#  ['sqft_lot', 'sqft_basement', 'lat'],
#  ['sqft_lot', 'sqft_basement', 'long'],
#  ['sqft_lot', 'sqft_basement', 'sqft_living15'],
#  ['sqft_lot', 'sqft_basement', 'sqft_lot15'],
#  ['sqft_lot', 'yr_built', 'yr_renovated'],
#  ['sqft_lot', 'yr_built', 'zipcode'],
#  ['sqft_lot', 'yr_built', 'lat'],
#  ['sqft_lot', 'yr_built', 'long'],
#  ['sqft_lot', 'yr_built', 'sqft_living15'],
#  ['sqft_lot', 'yr_built', 'sqft_lot15'],
#  ['sqft_lot', 'yr_renovated', 'zipcode'],
#  ['sqft_lot', 'yr_renovated', 'lat'],
#  ['sqft_lot', 'yr_renovated', 'long'],
#  ['sqft_lot', 'yr_renovated', 'sqft_living15'],
#  ['sqft_lot', 'yr_renovated', 'sqft_lot15'],
#  ['sqft_lot', 'zipcode', 'lat'],
#  ['sqft_lot', 'zipcode', 'long'],
#  ['sqft_lot', 'zipcode', 'sqft_living15'],
#  ['sqft_lot', 'zipcode', 'sqft_lot15'],
#  ['sqft_lot', 'lat', 'long'],
#  ['sqft_lot', 'lat', 'sqft_living15'],
#  ['sqft_lot', 'lat', 'sqft_lot15'],
#  ['sqft_lot', 'long', 'sqft_living15'],
#  ['sqft_lot', 'long', 'sqft_lot15'],
#  ['sqft_lot', 'sqft_living15', 'sqft_lot15'],
#  ['floors', 'waterfront', 'view'],
#  ['floors', 'waterfront', 'condition'],
#  ['floors', 'waterfront', 'grade'],
#  ['floors', 'waterfront', 'sqft_above'],
#  ['floors', 'waterfront', 'sqft_basement'],
#  ['floors', 'waterfront', 'yr_built'],
#  ['floors', 'waterfront', 'yr_renovated'],
#  ['floors', 'waterfront', 'zipcode'],
#  ['floors', 'waterfront', 'lat'],
#  ['floors', 'waterfront', 'long'],
#  ['floors', 'waterfront', 'sqft_living15'],
#  ['floors', 'waterfront', 'sqft_lot15'],
#  ['floors', 'view', 'condition'],
#  ['floors', 'view', 'grade'],
#  ['floors', 'view', 'sqft_above'],
#  ['floors', 'view', 'sqft_basement'],
#  ['floors', 'view', 'yr_built'],
#  ['floors', 'view', 'yr_renovated'],
#  ['floors', 'view', 'zipcode'],
#  ['floors', 'view', 'lat'],
#  ['floors', 'view', 'long'],
#  ['floors', 'view', 'sqft_living15'],
#  ['floors', 'view', 'sqft_lot15'],
#  ['floors', 'condition', 'grade'],
#  ['floors', 'condition', 'sqft_above'],
#  ['floors', 'condition', 'sqft_basement'],
#  ['floors', 'condition', 'yr_built'],
#  ['floors', 'condition', 'yr_renovated'],
#  ['floors', 'condition', 'zipcode'],
#  ['floors', 'condition', 'lat'],
#  ['floors', 'condition', 'long'],
#  ['floors', 'condition', 'sqft_living15'],
#  ['floors', 'condition', 'sqft_lot15'],
#  ['floors', 'grade', 'sqft_above'],
#  ['floors', 'grade', 'sqft_basement'],
#  ['floors', 'grade', 'yr_built'],
#  ['floors', 'grade', 'yr_renovated'],
#  ['floors', 'grade', 'zipcode'],
#  ['floors', 'grade', 'lat'],
#  ['floors', 'grade', 'long'],
#  ['floors', 'grade', 'sqft_living15'],
#  ['floors', 'grade', 'sqft_lot15'],
#  ['floors', 'sqft_above', 'sqft_basement'],
#  ['floors', 'sqft_above', 'yr_built'],
#  ['floors', 'sqft_above', 'yr_renovated'],
#  ['floors', 'sqft_above', 'zipcode'],
#  ['floors', 'sqft_above', 'lat'],
#  ['floors', 'sqft_above', 'long'],
#  ['floors', 'sqft_above', 'sqft_living15'],
#  ['floors', 'sqft_above', 'sqft_lot15'],
#  ['floors', 'sqft_basement', 'yr_built'],
#  ['floors', 'sqft_basement', 'yr_renovated'],
#  ['floors', 'sqft_basement', 'zipcode'],
#  ['floors', 'sqft_basement', 'lat'],
#  ['floors', 'sqft_basement', 'long'],
#  ['floors', 'sqft_basement', 'sqft_living15'],
#  ['floors', 'sqft_basement', 'sqft_lot15'],
#  ['floors', 'yr_built', 'yr_renovated'],
#  ['floors', 'yr_built', 'zipcode'],
#  ['floors', 'yr_built', 'lat'],
#  ['floors', 'yr_built', 'long'],
#  ['floors', 'yr_built', 'sqft_living15'],
#  ['floors', 'yr_built', 'sqft_lot15'],
#  ['floors', 'yr_renovated', 'zipcode'],
#  ['floors', 'yr_renovated', 'lat'],
#  ['floors', 'yr_renovated', 'long'],
#  ['floors', 'yr_renovated', 'sqft_living15'],
#  ['floors', 'yr_renovated', 'sqft_lot15'],
#  ['floors', 'zipcode', 'lat'],
#  ['floors', 'zipcode', 'long'],
#  ['floors', 'zipcode', 'sqft_living15'],
#  ['floors', 'zipcode', 'sqft_lot15'],
#  ['floors', 'lat', 'long'],
#  ['floors', 'lat', 'sqft_living15'],
#  ['floors', 'lat', 'sqft_lot15'],
#  ['floors', 'long', 'sqft_living15'],
#  ['floors', 'long', 'sqft_lot15'],
#  ['floors', 'sqft_living15', 'sqft_lot15'],
#  ['waterfront', 'view', 'condition'],
#  ['waterfront', 'view', 'grade'],
#  ['waterfront', 'view', 'sqft_above'],
#  ['waterfront', 'view', 'sqft_basement'],
#  ['waterfront', 'view', 'yr_built'],
#  ['waterfront', 'view', 'yr_renovated'],
#  ['waterfront', 'view', 'zipcode'],
#  ['waterfront', 'view', 'lat'],
#  ['waterfront', 'view', 'long'],
#  ['waterfront', 'view', 'sqft_living15'],
#  ['waterfront', 'view', 'sqft_lot15'],
#  ['waterfront', 'condition', 'grade'],
#  ['waterfront', 'condition', 'sqft_above'],
#  ['waterfront', 'condition', 'sqft_basement'],
#  ['waterfront', 'condition', 'yr_built'],
#  ['waterfront', 'condition', 'yr_renovated'],
#  ['waterfront', 'condition', 'zipcode'],
#  ['waterfront', 'condition', 'lat'],
#  ['waterfront', 'condition', 'long'],
#  ['waterfront', 'condition', 'sqft_living15'],
#  ['waterfront', 'condition', 'sqft_lot15'],
#  ['waterfront', 'grade', 'sqft_above'],
#  ['waterfront', 'grade', 'sqft_basement'],
#  ['waterfront', 'grade', 'yr_built'],
#  ['waterfront', 'grade', 'yr_renovated'],
#  ['waterfront', 'grade', 'zipcode'],
#  ['waterfront', 'grade', 'lat'],
#  ['waterfront', 'grade', 'long'],
#  ['waterfront', 'grade', 'sqft_living15'],
#  ['waterfront', 'grade', 'sqft_lot15'],
#  ['waterfront', 'sqft_above', 'sqft_basement'],
#  ['waterfront', 'sqft_above', 'yr_built'],
#  ['waterfront', 'sqft_above', 'yr_renovated'],
#  ['waterfront', 'sqft_above', 'zipcode'],
#  ['waterfront', 'sqft_above', 'lat'],
#  ['waterfront', 'sqft_above', 'long'],
#  ['waterfront', 'sqft_above', 'sqft_living15'],
#  ['waterfront', 'sqft_above', 'sqft_lot15'],
#  ['waterfront', 'sqft_basement', 'yr_built'],
#  ['waterfront', 'sqft_basement', 'yr_renovated'],
#  ['waterfront', 'sqft_basement', 'zipcode'],
#  ['waterfront', 'sqft_basement', 'lat'],
#  ['waterfront', 'sqft_basement', 'long'],
#  ['waterfront', 'sqft_basement', 'sqft_living15'],
#  ['waterfront', 'sqft_basement', 'sqft_lot15'],
#  ['waterfront', 'yr_built', 'yr_renovated'],
#  ['waterfront', 'yr_built', 'zipcode'],
#  ['waterfront', 'yr_built', 'lat'],
#  ['waterfront', 'yr_built', 'long'],
#  ['waterfront', 'yr_built', 'sqft_living15'],
#  ['waterfront', 'yr_built', 'sqft_lot15'],
#  ['waterfront', 'yr_renovated', 'zipcode'],
#  ['waterfront', 'yr_renovated', 'lat'],
#  ['waterfront', 'yr_renovated', 'long'],
#  ['waterfront', 'yr_renovated', 'sqft_living15'],
#  ['waterfront', 'yr_renovated', 'sqft_lot15'],
#  ['waterfront', 'zipcode', 'lat'],
#  ['waterfront', 'zipcode', 'long'],
#  ['waterfront', 'zipcode', 'sqft_living15'],
#  ['waterfront', 'zipcode', 'sqft_lot15'],
#  ['waterfront', 'lat', 'long'],
#  ['waterfront', 'lat', 'sqft_living15'],
#  ['waterfront', 'lat', 'sqft_lot15'],
#  ['waterfront', 'long', 'sqft_living15'],
#  ['waterfront', 'long', 'sqft_lot15'],
#  ['waterfront', 'sqft_living15', 'sqft_lot15'],
#  ['view', 'condition', 'grade'],
#  ['view', 'condition', 'sqft_above'],
#  ['view', 'condition', 'sqft_basement'],
#  ['view', 'condition', 'yr_built'],
#  ['view', 'condition', 'yr_renovated'],
#  ['view', 'condition', 'zipcode'],
#  ['view', 'condition', 'lat'],
#  ['view', 'condition', 'long'],
#  ['view', 'condition', 'sqft_living15'],
#  ['view', 'condition', 'sqft_lot15'],
#  ['view', 'grade', 'sqft_above'],
#  ['view', 'grade', 'sqft_basement'],
#  ['view', 'grade', 'yr_built'],
#  ['view', 'grade', 'yr_renovated'],
#  ['view', 'grade', 'zipcode'],
#  ['view', 'grade', 'lat'],
#  ['view', 'grade', 'long'],
#  ['view', 'grade', 'sqft_living15'],
#  ['view', 'grade', 'sqft_lot15'],
#  ['view', 'sqft_above', 'sqft_basement'],
#  ['view', 'sqft_above', 'yr_built'],
#  ['view', 'sqft_above', 'yr_renovated'],
#  ['view', 'sqft_above', 'zipcode'],
#  ['view', 'sqft_above', 'lat'],
#  ['view', 'sqft_above', 'long'],
#  ['view', 'sqft_above', 'sqft_living15'],
#  ['view', 'sqft_above', 'sqft_lot15'],
#  ['view', 'sqft_basement', 'yr_built'],
#  ['view', 'sqft_basement', 'yr_renovated'],
#  ['view', 'sqft_basement', 'zipcode'],
#  ['view', 'sqft_basement', 'lat'],
#  ['view', 'sqft_basement', 'long'],
#  ['view', 'sqft_basement', 'sqft_living15'],
#  ['view', 'sqft_basement', 'sqft_lot15'],
#  ['view', 'yr_built', 'yr_renovated'],
#  ['view', 'yr_built', 'zipcode'],
#  ['view', 'yr_built', 'lat'],
#  ['view', 'yr_built', 'long'],
#  ['view', 'yr_built', 'sqft_living15'],
#  ['view', 'yr_built', 'sqft_lot15'],
#  ['view', 'yr_renovated', 'zipcode'],
#  ['view', 'yr_renovated', 'lat'],
#  ['view', 'yr_renovated', 'long'],
#  ['view', 'yr_renovated', 'sqft_living15'],
#  ['view', 'yr_renovated', 'sqft_lot15'],
#  ['view', 'zipcode', 'lat'],
#  ['view', 'zipcode', 'long'],
#  ['view', 'zipcode', 'sqft_living15'],
#  ['view', 'zipcode', 'sqft_lot15'],
#  ['view', 'lat', 'long'],
#  ['view', 'lat', 'sqft_living15'],
#  ['view', 'lat', 'sqft_lot15'],
#  ['view', 'long', 'sqft_living15'],
#  ['view', 'long', 'sqft_lot15'],
#  ['view', 'sqft_living15', 'sqft_lot15'],
#  ['condition', 'grade', 'sqft_above'],
#  ['condition', 'grade', 'sqft_basement'],
#  ['condition', 'grade', 'yr_built'],
#  ['condition', 'grade', 'yr_renovated'],
#  ['condition', 'grade', 'zipcode'],
#  ['condition', 'grade', 'lat'],
#  ['condition', 'grade', 'long'],
#  ['condition', 'grade', 'sqft_living15'],
#  ['condition', 'grade', 'sqft_lot15'],
#  ['condition', 'sqft_above', 'sqft_basement'],
#  ['condition', 'sqft_above', 'yr_built'],
#  ['condition', 'sqft_above', 'yr_renovated'],
#  ['condition', 'sqft_above', 'zipcode'],
#  ['condition', 'sqft_above', 'lat'],
#  ['condition', 'sqft_above', 'long'],
#  ['condition', 'sqft_above', 'sqft_living15'],
#  ['condition', 'sqft_above', 'sqft_lot15'],
#  ['condition', 'sqft_basement', 'yr_built'],
#  ['condition', 'sqft_basement', 'yr_renovated'],
#  ['condition', 'sqft_basement', 'zipcode'],
#  ['condition', 'sqft_basement', 'lat'],
#  ['condition', 'sqft_basement', 'long'],
#  ['condition', 'sqft_basement', 'sqft_living15'],
#  ['condition', 'sqft_basement', 'sqft_lot15'],
#  ['condition', 'yr_built', 'yr_renovated'],
#  ['condition', 'yr_built', 'zipcode'],
#  ['condition', 'yr_built', 'lat'],
#  ['condition', 'yr_built', 'long'],
#  ['condition', 'yr_built', 'sqft_living15'],
#  ['condition', 'yr_built', 'sqft_lot15'],
#  ['condition', 'yr_renovated', 'zipcode'],
#  ['condition', 'yr_renovated', 'lat'],
#  ['condition', 'yr_renovated', 'long'],
#  ['condition', 'yr_renovated', 'sqft_living15'],
#  ['condition', 'yr_renovated', 'sqft_lot15'],
#  ['condition', 'zipcode', 'lat'],
#  ['condition', 'zipcode', 'long'],
#  ['condition', 'zipcode', 'sqft_living15'],
#  ['condition', 'zipcode', 'sqft_lot15'],
#  ['condition', 'lat', 'long'],
#  ['condition', 'lat', 'sqft_living15'],
#  ['condition', 'lat', 'sqft_lot15'],
#  ['condition', 'long', 'sqft_living15'],
#  ['condition', 'long', 'sqft_lot15'],
#  ['condition', 'sqft_living15', 'sqft_lot15'],
#  ['grade', 'sqft_above', 'sqft_basement'],
#  ['grade', 'sqft_above', 'yr_built'],
#  ['grade', 'sqft_above', 'yr_renovated'],
#  ['grade', 'sqft_above', 'zipcode'],
#  ['grade', 'sqft_above', 'lat'],
#  ['grade', 'sqft_above', 'long'],
#  ['grade', 'sqft_above', 'sqft_living15'],
#  ['grade', 'sqft_above', 'sqft_lot15'],
#  ['grade', 'sqft_basement', 'yr_built'],
#  ['grade', 'sqft_basement', 'yr_renovated'],
#  ['grade', 'sqft_basement', 'zipcode'],
#  ['grade', 'sqft_basement', 'lat'],
#  ['grade', 'sqft_basement', 'long'],
#  ['grade', 'sqft_basement', 'sqft_living15'],
#  ['grade', 'sqft_basement', 'sqft_lot15'],
#  ['grade', 'yr_built', 'yr_renovated'],
#  ['grade', 'yr_built', 'zipcode'],
#  ['grade', 'yr_built', 'lat'],
#  ['grade', 'yr_built', 'long'],
#  ['grade', 'yr_built', 'sqft_living15'],
#  ['grade', 'yr_built', 'sqft_lot15'],
#  ['grade', 'yr_renovated', 'zipcode'],
#  ['grade', 'yr_renovated', 'lat'],
#  ['grade', 'yr_renovated', 'long'],
#  ['grade', 'yr_renovated', 'sqft_living15'],
#  ['grade', 'yr_renovated', 'sqft_lot15'],
#  ['grade', 'zipcode', 'lat'],
#  ['grade', 'zipcode', 'long'],
#  ['grade', 'zipcode', 'sqft_living15'],
#  ['grade', 'zipcode', 'sqft_lot15'],
#  ['grade', 'lat', 'long'],
#  ['grade', 'lat', 'sqft_living15'],
#  ['grade', 'lat', 'sqft_lot15'],
#  ['grade', 'long', 'sqft_living15'],
#  ['grade', 'long', 'sqft_lot15'],
#  ['grade', 'sqft_living15', 'sqft_lot15'],
#  ['sqft_above', 'sqft_basement', 'yr_built'],
#  ['sqft_above', 'sqft_basement', 'yr_renovated'],
#  ['sqft_above', 'sqft_basement', 'zipcode'],
#  ['sqft_above', 'sqft_basement', 'lat'],
#  ['sqft_above', 'sqft_basement', 'long'],
#  ['sqft_above', 'sqft_basement', 'sqft_living15'],
#  ['sqft_above', 'sqft_basement', 'sqft_lot15'],
#  ['sqft_above', 'yr_built', 'yr_renovated'],
#  ['sqft_above', 'yr_built', 'zipcode'],
#  ['sqft_above', 'yr_built', 'lat'],
#  ['sqft_above', 'yr_built', 'long'],
#  ['sqft_above', 'yr_built', 'sqft_living15'],
#  ['sqft_above', 'yr_built', 'sqft_lot15'],
#  ['sqft_above', 'yr_renovated', 'zipcode'],
#  ['sqft_above', 'yr_renovated', 'lat'],
#  ['sqft_above', 'yr_renovated', 'long'],
#  ['sqft_above', 'yr_renovated', 'sqft_living15'],
#  ['sqft_above', 'yr_renovated', 'sqft_lot15'],
#  ['sqft_above', 'zipcode', 'lat'],
#  ['sqft_above', 'zipcode', 'long'],
#  ['sqft_above', 'zipcode', 'sqft_living15'],
#  ['sqft_above', 'zipcode', 'sqft_lot15'],
#  ['sqft_above', 'lat', 'long'],
#  ['sqft_above', 'lat', 'sqft_living15'],
#  ['sqft_above', 'lat', 'sqft_lot15'],
#  ['sqft_above', 'long', 'sqft_living15'],
#  ['sqft_above', 'long', 'sqft_lot15'],
#  ['sqft_above', 'sqft_living15', 'sqft_lot15'],
#  ['sqft_basement', 'yr_built', 'yr_renovated'],
#  ['sqft_basement', 'yr_built', 'zipcode'],
#  ['sqft_basement', 'yr_built', 'lat'],
#  ['sqft_basement', 'yr_built', 'long'],
#  ['sqft_basement', 'yr_built', 'sqft_living15'],
#  ['sqft_basement', 'yr_built', 'sqft_lot15'],
#  ['sqft_basement', 'yr_renovated', 'zipcode'],
#  ['sqft_basement', 'yr_renovated', 'lat'],
#  ['sqft_basement', 'yr_renovated', 'long'],
#  ['sqft_basement', 'yr_renovated', 'sqft_living15'],
#  ['sqft_basement', 'yr_renovated', 'sqft_lot15'],
#  ['sqft_basement', 'zipcode', 'lat'],
#  ['sqft_basement', 'zipcode', 'long'],
#  ['sqft_basement', 'zipcode', 'sqft_living15'],
#  ['sqft_basement', 'zipcode', 'sqft_lot15'],
#  ['sqft_basement', 'lat', 'long'],
#  ['sqft_basement', 'lat', 'sqft_living15'],
#  ['sqft_basement', 'lat', 'sqft_lot15'],
#  ['sqft_basement', 'long', 'sqft_living15'],
#  ['sqft_basement', 'long', 'sqft_lot15'],
#  ['sqft_basement', 'sqft_living15', 'sqft_lot15'],
#  ['yr_built', 'yr_renovated', 'zipcode'],
#  ['yr_built', 'yr_renovated', 'lat'],
#  ['yr_built', 'yr_renovated', 'long'],
#  ['yr_built', 'yr_renovated', 'sqft_living15'],
#  ['yr_built', 'yr_renovated', 'sqft_lot15'],
#  ['yr_built', 'zipcode', 'lat'],
#  ['yr_built', 'zipcode', 'long'],
#  ['yr_built', 'zipcode', 'sqft_living15'],
#  ['yr_built', 'zipcode', 'sqft_lot15'],
#  ['yr_built', 'lat', 'long'],
#  ['yr_built', 'lat', 'sqft_living15'],
#  ['yr_built', 'lat', 'sqft_lot15'],
#  ['yr_built', 'long', 'sqft_living15'],
#  ['yr_built', 'long', 'sqft_lot15'],
#  ['yr_built', 'sqft_living15', 'sqft_lot15'],
#  ['yr_renovated', 'zipcode', 'lat'],
#  ['yr_renovated', 'zipcode', 'long'],
#  ['yr_renovated', 'zipcode', 'sqft_living15'],
#  ['yr_renovated', 'zipcode', 'sqft_lot15'],
#  ['yr_renovated', 'lat', 'long'],
#  ['yr_renovated', 'lat', 'sqft_living15'],
#  ['yr_renovated', 'lat', 'sqft_lot15'],
#  ['yr_renovated', 'long', 'sqft_living15'],
#  ['yr_renovated', 'long', 'sqft_lot15'],
#  ['yr_renovated', 'sqft_living15', 'sqft_lot15'],
#  ['zipcode', 'lat', 'long'],
#  ['zipcode', 'lat', 'sqft_living15'],
#  ['zipcode', 'lat', 'sqft_lot15'],
#  ['zipcode', 'long', 'sqft_living15'],
#  ['zipcode', 'long', 'sqft_lot15'],
#  ['zipcode', 'sqft_living15', 'sqft_lot15'],
#  ['lat', 'long', 'sqft_living15'],
#  ['lat', 'long', 'sqft_lot15'],
#  ['lat', 'sqft_living15', 'sqft_lot15'],
#  ['long', 'sqft_living15', 'sqft_lot15'],
#  ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot'],
#  ['bedrooms', 'bathrooms', 'sqft_living', 'floors'],
#  ['bedrooms', 'bathrooms', 'sqft_living', 'waterfront'],
#  ['bedrooms', 'bathrooms', 'sqft_living', 'view'],
#  ['bedrooms', 'bathrooms', 'sqft_living', 'condition'],
#  ['bedrooms', 'bathrooms', 'sqft_living', 'grade'],
#  ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_above'],
#  ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_basement'],
#  ['bedrooms', 'bathrooms', 'sqft_living', 'yr_built'],
#  ['bedrooms', 'bathrooms', 'sqft_living', 'yr_renovated'],
#  ['bedrooms', 'bathrooms', 'sqft_living', 'zipcode'],
#  ['bedrooms', 'bathrooms', 'sqft_living', 'lat'],
#  ['bedrooms', 'bathrooms', 'sqft_living', 'long'],
#  ...]

# %% [markdown]
# ## Declare the dependent and independent variables

# %%
summary_df = pd.DataFrame(columns=['Model', 'Description','Root Mean Squared Error (RMSE)', 'R-squared (training)', 'Adjusted R-squared (training)','R-squared (test)', 'Adjusted R-squared (test)'])

target = df['price']
i = 0
for feature in tqdm(feature_list):
    features = df[feature]

    X_train, X_test, y_train, y_test = train_test_split(features, target, random_state=42,test_size=0.2)
    
    reg = LinearRegression()
    reg.fit(X_train,y_train)
    
    r2_train = reg.score(X_train, y_train)
    
    n = X_train.shape[0]
    p = X_train.shape[1]

    adjusted_r2_train = 1-(1-r2_train)*(n-1)/(n-p-1)
    
    y_train_pred = reg.predict(X_train)
    
    train_mae = metrics.mean_absolute_error(y_train, y_train_pred)
    train_mse = metrics.mean_squared_error(y_train, y_train_pred)
    train_rmse = np.sqrt(metrics.mean_squared_error(y_train, y_train_pred))
    
    r2_test = reg.score(X_test, y_test)
    n = X_test.shape[0]
    p = X_test.shape[1]

    adjusted_r2_test = 1-(1-r2_test)*(n-1)/(n-p-1)
    
    y_test_pred = reg.predict(X_test)
    
    test_mae = metrics.mean_absolute_error(y_test, y_test_pred)
    test_mse = metrics.mean_squared_error(y_test, y_test_pred)
    test_rmse = np.sqrt(metrics.mean_squared_error(y_test, y_test_pred))
    
    summary_df = summary_df.append({'Model' : i, 'Description' : feature , 'Root Mean Squared Error (RMSE)' : train_rmse, 'R-squared (training)' : r2_train, 'Adjusted R-squared (training)': adjusted_r2_train, 'R-squared (test)' : r2_test, 'Adjusted R-squared (test)' : adjusted_r2_test} , ignore_index=True)
    i += 1
# Out:
# HBox(children=(IntProgress(value=0, max=262143), HTML(value='')))

# %%
summary_df
# Out:
#          Model                                        Description  \
# 0            0                                         [bedrooms]
# 1            1                                        [bathrooms]
# 2            2                                      [sqft_living]
# 3            3                                         [sqft_lot]
# 4            4                                           [floors]
# ...        ...                                                ...
# 262138  262138  [bedrooms, bathrooms, sqft_living, floors, wat...
# 262139  262139  [bedrooms, bathrooms, sqft_lot, floors, waterf...
# 262140  262140  [bedrooms, sqft_living, sqft_lot, floors, wate...
# 262141  262141  [bathrooms, sqft_living, sqft_lot, floors, wat...
# 262142  262142  [bedrooms, bathrooms, sqft_living, sqft_lot, f...
#
#         Root Mean Squared Error (RMSE)  R-squared (training)  \
# 0                        357141.084823              0.094856
# 1                        319415.269058              0.275982
# 2                        266555.890933              0.495787
# 3                        374017.940805              0.007289
# 4                        362744.015518              0.066233
# ...                                ...                   ...
# 262138                   206664.215624              0.696912
# 262139                   206631.857848              0.697007
# 262140                   207378.434214              0.694814
# 262141                   208294.351277              0.692112
# 262142                   206631.857848              0.697007
#
#         Adjusted R-squared (training)  R-squared (test)  \
# 0                            0.094791          0.085027
# 1                            0.275930          0.270027
# 2                            0.495750          0.491225
# 3                            0.007217          0.007894
# 4                            0.066166          0.064638
# ...                               ...               ...
# 262138                       0.696539          0.702825
# 262139                       0.696634          0.702779
# 262140                       0.694438          0.700696
# 262141                       0.691733          0.696691
# 262142                       0.696612          0.702779
#
#         Adjusted R-squared (test)
# 0                        0.084763
# 1                        0.269816
# 2                        0.491078
# 3                        0.007607
# 4                        0.064367
# ...                           ...
# 262138                   0.701357
# 262139                   0.701310
# 262140                   0.699217
# 262141                   0.695192
# 262142                   0.701223
#
# [262143 rows x 7 columns]

# %%
summary_df.sort_values(['Root Mean Squared Error (RMSE)'])
# Out:
#          Model                                        Description  \
# 262142  262142  [bedrooms, bathrooms, sqft_living, sqft_lot, f...
# 262132  262132  [bedrooms, bathrooms, sqft_living, sqft_lot, f...
# 262131  262131  [bedrooms, bathrooms, sqft_living, sqft_lot, f...
# 262139  262139  [bedrooms, bathrooms, sqft_lot, floors, waterf...
# 262137  262137  [bedrooms, bathrooms, sqft_living, sqft_lot, w...
# ...        ...                                                ...
# 162        162                                    [zipcode, long]
# 13          13                                          [zipcode]
# 123        123                                  [condition, long]
# 7            7                                        [condition]
# 15          15                                             [long]
#
#         Root Mean Squared Error (RMSE)  R-squared (training)  \
# 262142                   206631.857848              0.697007
# 262132                   206631.857848              0.697007
# 262131                   206631.857848              0.697007
# 262139                   206631.857848              0.697007
# 262137                   206641.834824              0.696978
# ...                                ...                   ...
# 162                      374830.981371              0.002969
# 13                       374850.323805              0.002866
# 123                      374887.847893              0.002666
# 7                        375026.389268              0.001929
# 15                       375298.529760              0.000480
#
#         Adjusted R-squared (training)  R-squared (test)  \
# 262142                       0.696612          0.702779
# 262132                       0.696634          0.702779
# 262131                       0.696634          0.702779
# 262139                       0.696634          0.702779
# 262137                       0.696605          0.702732
# ...                               ...               ...
# 162                          0.002824         -0.000293
# 13                           0.002794         -0.000380
# 123                          0.002522         -0.002737
# 7                            0.001857         -0.002376
# 15                           0.000408         -0.000798
#
#         Adjusted R-squared (test)
# 262142                   0.701223
# 262132                   0.701310
# 262131                   0.701310
# 262139                   0.701310
# 262137                   0.701263
# ...                           ...
# 162                     -0.000872
# 13                      -0.000670
# 123                     -0.003317
# 7                       -0.002667
# 15                      -0.001087
#
# [262143 rows x 7 columns]

# %%
summary_df.to_csv (r'multi_linear_reg_summary.csv', index = False, header=True)
